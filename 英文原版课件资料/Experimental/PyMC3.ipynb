# %%
from __future__ import division
import os
import sys
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
# %precision 4
plt.style.use('ggplot')

# %%
np.random.seed(1234)
import pymc3 as pm
import scipy.stats as stats

# %%
import logging
_logger = logging.getLogger("theano.gof.compilelock")
_logger.setLevel(logging.ERROR)

# %% [markdown]
# PyMC3
# ----
#
# Install PyMC3 directly from GitHub with
# ```
# pip install --process-dependency-links git+https://github.com/pymc-devs/pymc3
# ```
#
# - [Repository for PyMC3](https://github.com/pymc-devs/pymc3)
# - [Getting started](http://pymc-devs.github.io/pymc3/getting_started/)
#
# PyMC3 is alpha software that is intended to improve on PyMC2 in the following ways (from GitHub page):
#
# - Intuitive model specification syntax, for example, x ~ N(0,1) translates to x = Normal(0,1)
# - Powerful sampling algorithms such as Hamiltonian Monte Carlo
# - Easy optimization for finding the maximum a posteriori point
# - Theano features
#     - Numpy broadcasting and advanced indexing
#     - Linear algebra operators
#     - Computation optimization and dynamic C compilation
# - Simple extensibility
#
# It also comes with extensive [examples](https://github.com/pymc-devs/pymc3/tree/master/pymc3/examples) including ports of the R/JAGS code examples from [Doing Bayesian Data Analysis](https://github.com/aloctavodia/Doing_bayesian_data_analysis).
#
# However, the API is different and it is not backwards compartible with models specified in PyMC2.

# %% [markdown]
# Examples
# ----

# %% [markdown]
# ### Coin toss
#
# We'll repeat the example of determining the bias of a coin from observed coin tosses. The likelihood is binomial, and  we use a beta prior.
#
# Note the different API from PyMC2.

# %%
n = 100
h = 61
alpha = 2
beta = 2

niter = 1000
with pm.Model() as model: # context management
    # define priors
    p = pm.Beta('p', alpha=alpha, beta=beta)
    
    # define likelihood
    y = pm.Binomial('y', n=n, p=p, observed=h)
    
    # inference
    start = pm.find_MAP() # Use MAP estimate (optimization) as the initial state for MCMC
    step = pm.Metropolis() # Have a choice of samplers
    trace = pm.sample(niter, step, start, random_seed=123, progressbar=True)
# Out:
#  [-----------------100%-----------------] 1000 of 1000 complete in 0.2 sec

# %%
plt.hist(trace['p'], 15, histtype='step', normed=True, label='post');
x = np.linspace(0, 1, 100)
plt.plot(x, stats.beta.pdf(x, alpha, beta), label='prior');
plt.legend(loc='best');

# %% [markdown]
# ### Estimating mean and standard deviation of normal distribution
#
# $$
# X \sim \mathcal{N}(\mu, \sigma^2)
# $$

# %%
# generate observed data
N = 100
_mu = np.array([10])
_sigma = np.array([2])
y = np.random.normal(_mu, _sigma, N)

niter = 1000
with pm.Model() as model:
    # define priors
    mu = pm.Uniform('mu', lower=0, upper=100, shape=_mu.shape)
    sigma = pm.Uniform('sigma', lower=0, upper=10, shape=_sigma.shape)
    
    # define likelihood
    y_obs = pm.Normal('Y_obs', mu=mu, sd=sigma, observed=y)
    
    # inference
    start = pm.find_MAP()
    step = pm.Slice()
    trace = pm.sample(niter, step, start, random_seed=123, progressbar=True)
# Out:
#  [------------     32%                  ] 320 of 1000 complete in 0.5 sec
#  [-----------------59%--                ] 597 of 1000 complete in 1.0 sec
#  [-----------------83%-----------       ] 835 of 1000 complete in 1.5 sec
#  [-----------------100%-----------------] 1000 of 1000 complete in 1.9 sec

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1); 
plt.hist(trace['mu'][-niter/2:,0], 25, histtype='step');
plt.subplot(1,2,2); 
plt.hist(trace['sigma'][-niter/2:,0], 25, histtype='step');

# %% [markdown]
# ### Estimating parameters of a linear regreession model
#
# We will show how to estimate regression parameters using a simple linear modesl
#
# $$
# y \sim ax + b
# $$
#
# We can restate the linear model $$y = ax + b + \epsilon$$ as sampling from a probability distribution
#
# $$
# y \sim \mathcal{N}(ax + b, \sigma^2)
# $$
#
# Now we can use pymc to estimate the paramters $a$, $b$ and $\sigma$ (pymc2 uses precision $\tau$ which is $1/\sigma^2$ so we need to do a simple transformation). We will assume the following priors
#
# $$
# a \sim \mathcal{N}(0, 100) \\
# b \sim \mathcal{N}(0, 100) \\
# \tau \sim \text{Gamma}(0.1, 0.1)
# $$

# %%
# observed data
n = 11
_a = 6
_b = 2
x = np.linspace(0, 1, n)
y = _a*x + _b + np.random.randn(n)

with pm.Model() as model:
    a = pm.Normal('a', mu=0, sd=20)
    b = pm.Normal('b', mu=0, sd=20)
    sigma = pm.Uniform('sigma', lower=0, upper=20)
    
    y_est = a*x + b # simple auxiliary variables
    
    likelihood = pm.Normal('y', mu=y_est, sd=sigma, observed=y)
    # inference
    start = pm.find_MAP()
    step = pm.NUTS() # Hamiltonian MCMC with No U-Turn Sampler
    trace = pm.sample(niter, step, start, random_seed=123, progressbar=True)
    pm.traceplot(trace);
# Out:
#  [-                 2%                  ] 29 of 1000 complete in 0.5 sec
#  [-                 5%                  ] 51 of 1000 complete in 1.0 sec
#  [---               9%                  ] 94 of 1000 complete in 1.5 sec
#  [-----            14%                  ] 148 of 1000 complete in 2.1 sec
#  [-------          21%                  ] 210 of 1000 complete in 2.6 sec
#  [---------        26%                  ] 260 of 1000 complete in 3.1 sec
#  [-----------      30%                  ] 300 of 1000 complete in 3.6 sec
#  [-------------    35%                  ] 357 of 1000 complete in 4.1 sec
#  [---------------- 42%                  ] 425 of 1000 complete in 4.6 sec
#  [-----------------47%                  ] 473 of 1000 complete in 5.1 sec
#  [-----------------53%                  ] 534 of 1000 complete in 5.6 sec
#  [-----------------60%---               ] 606 of 1000 complete in 6.1 sec
#  [-----------------67%-----             ] 673 of 1000 complete in 6.6 sec
#  [-----------------75%--------          ] 752 of 1000 complete in 7.1 sec
#  [-----------------82%-----------       ] 825 of 1000 complete in 7.6 sec
#  [-----------------89%-------------     ] 891 of 1000 complete in 8.1 sec
#  [-----------------95%----------------  ] 953 of 1000 complete in 8.6 sec
#  [-----------------100%-----------------] 1000 of 1000 complete in 8.9 sec

# %% [markdown]
# ### Alternative fromulation using GLM formulas

# %%
data = dict(x=x, y=y)

with pm.Model() as model:
    pm.glm.glm('y ~ x', data)
    step = pm.NUTS() 
    trace = pm.sample(2000, step, progressbar=True)
# Out:
#  [-                 4%                  ] 87 of 2000 complete in 0.5 sec
#  [----             10%                  ] 212 of 2000 complete in 1.0 sec
#  [-----            14%                  ] 298 of 2000 complete in 1.5 sec
#  [--------         21%                  ] 423 of 2000 complete in 2.0 sec
#  [----------       27%                  ] 553 of 2000 complete in 2.5 sec
#  [------------     33%                  ] 668 of 2000 complete in 3.0 sec
#  [---------------  40%                  ] 811 of 2000 complete in 3.5 sec
#  [-----------------46%                  ] 931 of 2000 complete in 4.0 sec
#  [-----------------53%                  ] 1075 of 2000 complete in 4.5 sec
#  [-----------------60%---               ] 1213 of 2000 complete in 5.0 sec
#  [-----------------66%-----             ] 1335 of 2000 complete in 5.5 sec
#  [-----------------73%-------           ] 1469 of 2000 complete in 6.0 sec
#  [-----------------80%----------        ] 1603 of 2000 complete in 6.5 sec
#  [-----------------86%------------      ] 1734 of 2000 complete in 7.0 sec
#  [-----------------92%---------------   ] 1858 of 2000 complete in 7.6 sec
#  [-----------------99%----------------- ] 1994 of 2000 complete in 8.1 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 8.1 sec

# %%
pm.traceplot(trace);

# %%
plt.figure(figsize=(7, 7))
plt.scatter(x, y, s=30, label='data')
pm.glm.plot_posterior_predictive(trace, samples=100, 
                                 label='posterior predictive regression lines', 
                                 c='blue', alpha=0.2)
plt.plot(x, _a*x + _b, label='true regression line', lw=3., c='red')
plt.legend(loc='best');

# %% [markdown]
# ### Simple Logistic model
#
# We have observations of height and weight and want to use a logistic model to guess the sex.

# %%
# observed data
df = pd.read_csv('HtWt.csv')
df.head()
# Out:
#    male  height  weight
# 0     0    63.2   168.7
# 1     0    68.7   169.8
# 2     0    64.8   176.6
# 3     0    67.9   246.8
# 4     1    68.9   151.6

# %%
niter = 1000
with pm.Model() as model:
    pm.glm.glm('male ~ height + weight', df, family=pm.glm.families.Binomial()) 
    trace = pm.sample(niter, step=pm.Slice(), random_seed=123, progressbar=True)
# Out:
#  [-------          19%                  ] 191 of 1000 complete in 0.5 sec
#  [-------------    36%                  ] 367 of 1000 complete in 1.0 sec
#  [-----------------52%                  ] 529 of 1000 complete in 1.5 sec
#  [-----------------68%-----             ] 680 of 1000 complete in 2.0 sec
#  [-----------------81%-----------       ] 817 of 1000 complete in 2.5 sec
#  [-----------------95%----------------  ] 950 of 1000 complete in 3.0 sec
#  [-----------------100%-----------------] 1000 of 1000 complete in 3.2 sec

# %%
# note that height and weigth in trace refer to the coefficients

df_trace = pm.trace_to_dataframe(trace)
pd.scatter_matrix(df_trace[-1000:], diagonal='kde');

# %%
plt.figure(figsize=(12, 4))
plt.subplot(121)
plt.plot(df_trace.ix[-1000:, 'height'], linewidth=0.7)
plt.subplot(122)
plt.plot(df_trace.ix[-1000:, 'weight'], linewidth=0.7);

# %% [markdown]
# ### There is no convergence!
#
# Becaue of ths strong correlation between height and weight, a one-at-a-time sampler such as the slice or Gibbs sampler will take a long time to converge. The HMC does much better.

# %%
niter = 1000
with pm.Model() as model:
    pm.glm.glm('male ~ height + weight', df, family=pm.glm.families.Binomial()) 
    trace = pm.sample(niter, step=pm.NUTS(), random_seed=123, progressbar=True)
# Out:
#  [                  0%                  ] 5 of 1000 complete in 0.5 sec
#  [                  1%                  ] 18 of 1000 complete in 1.3 sec
#  [-                 3%                  ] 35 of 1000 complete in 1.8 sec
#  [-                 4%                  ] 49 of 1000 complete in 2.4 sec
#  [--                6%                  ] 60 of 1000 complete in 2.9 sec
#  [---               8%                  ] 87 of 1000 complete in 3.4 sec
#  [---               9%                  ] 96 of 1000 complete in 3.9 sec
#  [----             12%                  ] 121 of 1000 complete in 4.5 sec
#  [-----            14%                  ] 142 of 1000 complete in 5.0 sec
#  [-----            15%                  ] 156 of 1000 complete in 5.5 sec
#  [------           17%                  ] 170 of 1000 complete in 6.1 sec
#  [-------          18%                  ] 188 of 1000 complete in 6.6 sec
#  [-------          20%                  ] 202 of 1000 complete in 7.1 sec
#  [--------         22%                  ] 222 of 1000 complete in 7.6 sec
#  [---------        23%                  ] 237 of 1000 complete in 8.1 sec
#  [---------        25%                  ] 257 of 1000 complete in 8.6 sec
#  [----------       28%                  ] 283 of 1000 complete in 9.1 sec
#  [-----------      30%                  ] 306 of 1000 complete in 9.6 sec
#  [------------     33%                  ] 330 of 1000 complete in 10.2 sec
#  [-------------    35%                  ] 350 of 1000 complete in 10.7 sec
#  [-------------    36%                  ] 363 of 1000 complete in 11.2 sec
#  [--------------   38%                  ] 384 of 1000 complete in 11.7 sec
#  [---------------  40%                  ] 407 of 1000 complete in 12.2 sec
#  [---------------  42%                  ] 420 of 1000 complete in 12.8 sec
#  [---------------- 44%                  ] 440 of 1000 complete in 13.3 sec
#  [-----------------46%                  ] 465 of 1000 complete in 13.8 sec
#  [-----------------48%                  ] 487 of 1000 complete in 14.3 sec
#  [-----------------51%                  ] 510 of 1000 complete in 14.9 sec
#  [-----------------53%                  ] 533 of 1000 complete in 15.4 sec
#  [-----------------55%-                 ] 555 of 1000 complete in 15.9 sec
#  [-----------------57%-                 ] 574 of 1000 complete in 16.4 sec
#  [-----------------59%--                ] 591 of 1000 complete in 16.9 sec
#  [-----------------62%---               ] 620 of 1000 complete in 17.4 sec
#  [-----------------64%----              ] 642 of 1000 complete in 18.0 sec
#  [-----------------65%----              ] 654 of 1000 complete in 18.5 sec
#  [-----------------67%-----             ] 673 of 1000 complete in 19.0 sec
#  [-----------------70%------            ] 702 of 1000 complete in 19.6 sec
#  [-----------------71%-------           ] 715 of 1000 complete in 20.1 sec
#  [-----------------73%--------          ] 738 of 1000 complete in 20.6 sec
#  [-----------------75%--------          ] 759 of 1000 complete in 21.2 sec
#  [-----------------78%---------         ] 782 of 1000 complete in 21.7 sec
#  [-----------------80%----------        ] 804 of 1000 complete in 22.2 sec
#  [-----------------82%-----------       ] 826 of 1000 complete in 22.8 sec
#  [-----------------84%------------      ] 844 of 1000 complete in 23.3 sec
#  [-----------------86%------------      ] 868 of 1000 complete in 23.8 sec
#  [-----------------88%-------------     ] 886 of 1000 complete in 24.3 sec
#  [-----------------90%--------------    ] 909 of 1000 complete in 24.9 sec
#  [-----------------94%---------------   ] 943 of 1000 complete in 25.4 sec
#  [-----------------96%----------------  ] 967 of 1000 complete in 25.9 sec
#  [-----------------98%----------------- ] 982 of 1000 complete in 26.4 sec
#  [-----------------100%-----------------] 1001 of 1000 complete in 27.0 sec

# %%
df_trace = pm.trace_to_dataframe(trace)
pd.scatter_matrix(df_trace[-1000:], diagonal='kde');

# %%
pm.summary(trace);
# Out:
# Intercept:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   -51.393          11.299           0.828            [-73.102, -29.353]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -76.964        -58.534        -50.383        -43.856        -30.630
#
#
# height:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.747            0.170            0.012            [0.422, 1.096]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.453          0.630          0.732          0.853          1.139
#
#
# weight:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.011            0.012            0.001            [-0.012, 0.034]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -0.012         0.002          0.010          0.019          0.034

# %%
import seaborn as sn
sn.kdeplot(trace['weight'], trace['height'])
plt.xlabel('Weight', fontsize=20)
plt.ylabel('Height', fontsize=20)
plt.style.use('ggplot')

# %% [markdown]
# We can use the logistic regression results to classify subjects as male or female based on their height and weight, using 0.5 as a cutoff, as shown in the plot below. Green = true positive male, yellow = true positive female, red halo = misclassification. Blue line shows the 0.5 cutoff.

# %%
intercept, height, weight = df_trace[-niter//2:].mean(0)

def predict(w, h, height=height, weight=weight):
    """Predict gender given weight (w) and height (h) values."""
    v = intercept + height*h + weight*w
    return np.exp(v)/(1+np.exp(v))

# calculate predictions on grid
xs = np.linspace(df.weight.min(), df.weight.max(), 100)
ys = np.linspace(df.height.min(), df.height.max(), 100)
X, Y = np.meshgrid(xs, ys)
Z = predict(X, Y)

plt.figure(figsize=(6,6))

# plot 0.5 contour line - classify as male if above this line
plt.contour(X, Y, Z, levels=[0.5])

# classify all subjects
colors = ['lime' if i else 'yellow' for i in df.male]
ps = predict(df.weight, df.height)
errs = ((ps < 0.5) & df.male) |((ps >= 0.5) & (1-df.male))
plt.scatter(df.weight[errs], df.height[errs], facecolors='red', s=150)
plt.scatter(df.weight, df.height, facecolors=colors, edgecolors='k', s=50, alpha=1);
plt.xlabel('Weight', fontsize=16)
plt.ylabel('Height', fontsize=16)
plt.title('Gender classification by weight and height', fontsize=16)
plt.tight_layout();

# %% [markdown]
# ### Estimating parameters of a logistic model
#
# Gelman's book has an example where the dose of a drug may be affected to the number of rat deaths in an experiment.
#
# | Dose (log g/ml) | # Rats | # Deaths |
# |-----------------|--------|----------|
# | -0.896          | 5      | 0        |
# | -0.296          | 5      | 1        |
# | -0.053          | 5      | 3        |
# | 0.727           | 5      | 5        |
#
# We will model the number of deaths as a random sample from a binomial distribution, where $n$ is the number of rats and $p$ the probabbility of a rat dying. We are given $n = 5$, but we believve that $p$ may be related to the drug dose $x$. As $x$ increases the number of rats dying seems to increase, and since $p$ is a probability, we use the following model:
#
# $$
# y \sim \text{Bin}(n, p) \\
# \text{logit}(p) = \alpha + \beta x \\
# \alpha \sim \mathcal{N}(0, 5) \\
# \beta \sim \mathcal{N}(0, 10)
# $$
#
# where we set vague priors for $\alpha$ and $\beta$, the parameters for the logistic model.

# %%
# observed data
n = 5 * np.ones(4)
x = np.array([-0.896, -0.296, -0.053, 0.727])
y = np.array([0, 1, 3, 5])

def invlogit(x):
    return pm.exp(x) / (1 + pm.exp(x))

with pm.Model() as model:
    # define priors
    alpha = pm.Normal('alpha', mu=0, sd=5)
    beta = pm.Flat('beta')
    
    # define likelihood
    p = invlogit(alpha + beta*x)
    y_obs = pm.Binomial('y_obs', n=n, p=p, observed=y)
    
    # inference
    start = pm.find_MAP()
    step = pm.NUTS()
    trace = pm.sample(niter, step, start, random_seed=123, progressbar=True)
# Out:
#  [------           16%                  ] 163 of 1000 complete in 0.5 sec
#  [-------------    36%                  ] 367 of 1000 complete in 1.0 sec
#  [-----------------58%--                ] 581 of 1000 complete in 1.5 sec
#  [-----------------78%---------         ] 784 of 1000 complete in 2.0 sec
#  [-----------------100%-----------------] 1000 of 1000 complete in 2.5 sec

# %%
np.exp
# Out:
# <ufunc 'exp'>

# %%
f = lambda a, b, xp: np.exp(a + b*xp)/(1 + np.exp(a + b*xp))

xp = np.linspace(-1, 1, 100)
a = trace.get_values('alpha').mean()
b = trace.get_values('beta').mean()
plt.plot(xp, f(a, b, xp))
plt.scatter(x, y/5, s=50);
plt.xlabel('Log does of drug')
plt.ylabel('Risk of death');

# %% [markdown]
# ### Using a hierarchcical model
#
# This uses the Gelman radon data set and is based off this [IPython notebook](http://twiecki.github.io/blog/2014/03/17/bayesian-glms-3/). Radon levels were measured in houses from all counties in several states. Here we want to know if the preence of a basement affects the level of radon, and if this is affected by which county the house is located in.
#
# The data set provided is just for the state of Minnesota, which has 85 counties with 2 to 116 measurements per county. We only need 3 columns for this example `county`, `log_radon`, `floor`, where `floor=0` indicates that there is a basement.
#
# We will perfrom simple linear regression on log_radon as a function of county and floor.

# %%
radon = pd.read_csv('radon.csv')[['county', 'floor', 'log_radon']]
radon.head()
# Out:
#    county  floor  log_radon
# 0  AITKIN      1   0.832909
# 1  AITKIN      0   0.832909
# 2  AITKIN      0   1.098612
# 3  AITKIN      0   0.095310
# 4   ANOKA      0   1.163151

# %% [markdown]
# #### Hiearchical model
#
# With a hierarchical model, there is an $a_c$ and a $b_c$ for each county $c$ just as in the individual couty model, but they are no longer indepnedent but assumed to come from a common group distribution
#
# $$
# a_c \sim \mathcal{N}(\mu_a, \sigma_a^2) \\
# b_c \sim \mathcal{N}(\mu_b, \sigma_b^2)
# $$
#
# we furhter assume that the hyperparameters come from the following distributions
#
# $$
# \mu_a \sim \mathcal{N}(0, 100^2) \\
# \sigma_a \sim \mathcal{U}(0, 100) \\
# \mu_b \sim \mathcal{N}(0, 100^2) \\
# \sigma_b \sim \mathcal{U}(0, 100)
# $$

# %%
county = pd.Categorical(radon['county']).codes

with pm.Model() as hm:
    # County hyperpriors
    mu_a = pm.Normal('mu_a', mu=0, tau=1.0/100**2)
    sigma_a = pm.Uniform('sigma_a', lower=0, upper=100)
    mu_b = pm.Normal('mu_b', mu=0, tau=1.0/100**2)
    sigma_b = pm.Uniform('sigma_b', lower=0, upper=100)
    
    # County slopes and intercepts
    a = pm.Normal('slope', mu=mu_a, sd=sigma_a, shape=len(set(county)))
    b = pm.Normal('intercept', mu=mu_b, tau=1.0/sigma_b**2, shape=len(set(county)))
    
    # Houseehold errors
    sigma = pm.Gamma("sigma", alpha=10, beta=1)
    
    # Model prediction of radon level
    mu = a[county] + b[county] * radon.floor.values
    
    # Data likelihood
    y = pm.Normal('y', mu=mu, sd=sigma, observed=radon.log_radon)

# %%
with hm:
    start = pm.find_MAP()
    step = pm.NUTS(scaling=start)
    hm_trace = pm.sample(2000, step, start=start, random_seed=123, progressbar=True)
# Out:
#  [                  0%                  ] 6 of 2000 complete in 4.3 sec
#  [                  0%                  ] 7 of 2000 complete in 8.7 sec
#  [                  0%                  ] 8 of 2000 complete in 11.0 sec
#  [                  0%                  ] 9 of 2000 complete in 13.2 sec
#  [                  0%                  ] 10 of 2000 complete in 13.8 sec
#  [                  0%                  ] 12 of 2000 complete in 22.8 sec
#  [                  0%                  ] 13 of 2000 complete in 27.2 sec
#  [                  0%                  ] 14 of 2000 complete in 29.5 sec
#  [                  0%                  ] 15 of 2000 complete in 30.6 sec
#  [                  0%                  ] 16 of 2000 complete in 31.1 sec
#  [                  0%                  ] 18 of 2000 complete in 31.7 sec
#  [                  0%                  ] 19 of 2000 complete in 32.3 sec
#  [                  1%                  ] 22 of 2000 complete in 37.1 sec
#  [                  1%                  ] 23 of 2000 complete in 39.3 sec
#  [                  1%                  ] 24 of 2000 complete in 40.4 sec
#  [                  1%                  ] 25 of 2000 complete in 41.0 sec
#  [                  1%                  ] 28 of 2000 complete in 41.9 sec
#  [                  1%                  ] 30 of 2000 complete in 44.4 sec
#  [                  1%                  ] 31 of 2000 complete in 45.5 sec
#  [                  1%                  ] 32 of 2000 complete in 46.6 sec
#  [                  1%                  ] 33 of 2000 complete in 47.2 sec
#  [                  1%                  ] 34 of 2000 complete in 48.3 sec
#  [                  1%                  ] 35 of 2000 complete in 48.9 sec
#  [                  1%                  ] 36 of 2000 complete in 49.4 sec
#  [                  1%                  ] 39 of 2000 complete in 50.8 sec
#  [                  2%                  ] 40 of 2000 complete in 51.4 sec
#  [                  2%                  ] 41 of 2000 complete in 51.9 sec
#  [                  2%                  ] 42 of 2000 complete in 52.5 sec
#  [                  2%                  ] 44 of 2000 complete in 54.9 sec
#  [                  2%                  ] 45 of 2000 complete in 56.0 sec
#  [                  2%                  ] 46 of 2000 complete in 56.5 sec
#  [                  2%                  ] 47 of 2000 complete in 57.1 sec
#  [                  2%                  ] 48 of 2000 complete in 57.6 sec
#  [                  2%                  ] 50 of 2000 complete in 59.0 sec
#  [                  2%                  ] 51 of 2000 complete in 59.6 sec
#  [-                 2%                  ] 53 of 2000 complete in 60.4 sec
#  [-                 2%                  ] 54 of 2000 complete in 61.0 sec
#  [-                 2%                  ] 55 of 2000 complete in 61.5 sec
#  [-                 2%                  ] 57 of 2000 complete in 63.8 sec
#  [-                 2%                  ] 58 of 2000 complete in 64.9 sec
#  [-                 2%                  ] 59 of 2000 complete in 66.1 sec
#  [-                 3%                  ] 60 of 2000 complete in 66.6 sec
#  [-                 3%                  ] 61 of 2000 complete in 67.2 sec
#  [-                 3%                  ] 62 of 2000 complete in 67.7 sec
#  [-                 3%                  ] 64 of 2000 complete in 70.2 sec
#  [-                 3%                  ] 65 of 2000 complete in 71.3 sec
#  [-                 3%                  ] 66 of 2000 complete in 71.9 sec
#  [-                 3%                  ] 67 of 2000 complete in 72.5 sec
#  [-                 3%                  ] 68 of 2000 complete in 73.0 sec
#  [-                 3%                  ] 70 of 2000 complete in 75.3 sec
#  [-                 3%                  ] 71 of 2000 complete in 77.5 sec
#  [-                 3%                  ] 72 of 2000 complete in 78.6 sec
#  [-                 3%                  ] 73 of 2000 complete in 79.7 sec
#  [-                 3%                  ] 74 of 2000 complete in 80.8 sec
#  [-                 3%                  ] 75 of 2000 complete in 81.9 sec
#  [-                 3%                  ] 76 of 2000 complete in 82.5 sec
#  [-                 3%                  ] 77 of 2000 complete in 83.0 sec
#  [-                 3%                  ] 78 of 2000 complete in 84.2 sec
#  [-                 3%                  ] 79 of 2000 complete in 84.7 sec
#  [-                 4%                  ] 81 of 2000 complete in 86.3 sec
#  [-                 4%                  ] 82 of 2000 complete in 87.4 sec
#  [-                 4%                  ] 83 of 2000 complete in 88.5 sec
#  [-                 4%                  ] 84 of 2000 complete in 89.0 sec
#  [-                 4%                  ] 85 of 2000 complete in 89.6 sec
#  [-                 4%                  ] 88 of 2000 complete in 91.0 sec
#  [-                 4%                  ] 89 of 2000 complete in 91.6 sec
#  [-                 4%                  ] 90 of 2000 complete in 92.1 sec
#  [-                 4%                  ] 91 of 2000 complete in 92.7 sec
#  [-                 4%                  ] 93 of 2000 complete in 93.2 sec
#  [-                 4%                  ] 96 of 2000 complete in 94.9 sec
#  [-                 4%                  ] 97 of 2000 complete in 95.4 sec
#  [-                 4%                  ] 98 of 2000 complete in 96.0 sec
#  [-                 4%                  ] 99 of 2000 complete in 96.5 sec
#  [-                 5%                  ] 101 of 2000 complete in 97.1 sec
#  [-                 5%                  ] 104 of 2000 complete in 98.6 sec
#  [-                 5%                  ] 105 of 2000 complete in 99.2 sec
#  [--                5%                  ] 106 of 2000 complete in 99.8 sec
#  [--                5%                  ] 107 of 2000 complete in 100.3 sec
#  [--                5%                  ] 108 of 2000 complete in 100.9 sec
#  [--                5%                  ] 109 of 2000 complete in 101.4 sec
#  [--                5%                  ] 112 of 2000 complete in 102.9 sec
#  [--                5%                  ] 113 of 2000 complete in 103.5 sec
#  [--                5%                  ] 114 of 2000 complete in 104.1 sec
#  [--                5%                  ] 115 of 2000 complete in 104.7 sec
#  [--                5%                  ] 118 of 2000 complete in 106.2 sec
#  [--                5%                  ] 119 of 2000 complete in 106.8 sec
#  [--                6%                  ] 120 of 2000 complete in 107.4 sec
#  [--                6%                  ] 121 of 2000 complete in 107.9 sec
#  [--                6%                  ] 123 of 2000 complete in 110.3 sec
#  [--                6%                  ] 124 of 2000 complete in 111.5 sec
#  [--                6%                  ] 125 of 2000 complete in 112.6 sec
#  [--                6%                  ] 126 of 2000 complete in 113.2 sec
#  [--                6%                  ] 127 of 2000 complete in 113.7 sec
#  [--                6%                  ] 128 of 2000 complete in 114.3 sec
#  [--                6%                  ] 129 of 2000 complete in 114.9 sec
#  [--                6%                  ] 130 of 2000 complete in 116.0 sec
#  [--                6%                  ] 131 of 2000 complete in 117.1 sec
#  [--                6%                  ] 132 of 2000 complete in 118.2 sec
#  [--                6%                  ] 133 of 2000 complete in 118.8 sec
#  [--                6%                  ] 134 of 2000 complete in 119.3 sec
#  [--                6%                  ] 135 of 2000 complete in 119.9 sec
#  [--                6%                  ] 137 of 2000 complete in 120.4 sec
#  [--                6%                  ] 139 of 2000 complete in 121.6 sec
#  [--                7%                  ] 140 of 2000 complete in 122.2 sec
#  [--                7%                  ] 141 of 2000 complete in 122.8 sec
#  [--                7%                  ] 142 of 2000 complete in 123.3 sec
#  [--                7%                  ] 143 of 2000 complete in 124.4 sec
#  [--                7%                  ] 144 of 2000 complete in 125.6 sec
#  [--                7%                  ] 145 of 2000 complete in 126.1 sec
#  [--                7%                  ] 146 of 2000 complete in 126.7 sec
#  [--                7%                  ] 147 of 2000 complete in 127.2 sec
#  [--                7%                  ] 150 of 2000 complete in 128.7 sec
#  [--                7%                  ] 151 of 2000 complete in 129.3 sec
#  [--                7%                  ] 153 of 2000 complete in 130.7 sec
#  [--                7%                  ] 154 of 2000 complete in 131.8 sec
#  [--                7%                  ] 155 of 2000 complete in 133.0 sec
#  [--                7%                  ] 156 of 2000 complete in 133.5 sec
#  [--                7%                  ] 157 of 2000 complete in 134.1 sec
#  [---               7%                  ] 158 of 2000 complete in 134.7 sec
#  [---               7%                  ] 159 of 2000 complete in 135.3 sec
#  [---               8%                  ] 160 of 2000 complete in 135.8 sec
#  [---               8%                  ] 161 of 2000 complete in 136.4 sec
#  [---               8%                  ] 162 of 2000 complete in 136.9 sec
#  [---               8%                  ] 164 of 2000 complete in 137.5 sec
#  [---               8%                  ] 165 of 2000 complete in 138.1 sec
#  [---               8%                  ] 166 of 2000 complete in 138.6 sec
#  [---               8%                  ] 167 of 2000 complete in 139.8 sec
#  [---               8%                  ] 168 of 2000 complete in 140.3 sec
#  [---               8%                  ] 169 of 2000 complete in 140.9 sec
#  [---               8%                  ] 170 of 2000 complete in 141.4 sec
#  [---               8%                  ] 171 of 2000 complete in 142.0 sec
#  [---               8%                  ] 172 of 2000 complete in 142.6 sec
#  [---               8%                  ] 173 of 2000 complete in 143.1 sec
#  [---               8%                  ] 174 of 2000 complete in 143.7 sec
#  [---               8%                  ] 176 of 2000 complete in 144.5 sec
#  [---               8%                  ] 177 of 2000 complete in 145.1 sec
#  [---               8%                  ] 178 of 2000 complete in 145.6 sec
#  [---               8%                  ] 179 of 2000 complete in 146.2 sec
#  [---               9%                  ] 181 of 2000 complete in 147.0 sec
#  [---               9%                  ] 183 of 2000 complete in 147.6 sec
#  [---               9%                  ] 186 of 2000 complete in 148.4 sec
#  [---               9%                  ] 187 of 2000 complete in 149.0 sec
#  [---               9%                  ] 188 of 2000 complete in 149.5 sec
#  [---               9%                  ] 189 of 2000 complete in 150.1 sec
#  [---               9%                  ] 191 of 2000 complete in 151.2 sec
#  [---               9%                  ] 192 of 2000 complete in 151.8 sec
#  [---               9%                  ] 193 of 2000 complete in 152.3 sec
#  [---               9%                  ] 194 of 2000 complete in 152.9 sec
#  [---               9%                  ] 196 of 2000 complete in 153.7 sec
#  [---               9%                  ] 197 of 2000 complete in 154.3 sec
#  [---               9%                  ] 198 of 2000 complete in 154.8 sec
#  [---               9%                  ] 199 of 2000 complete in 155.4 sec
#  [---              10%                  ] 200 of 2000 complete in 156.0 sec
#  [---              10%                  ] 201 of 2000 complete in 156.5 sec
#  [---              10%                  ] 202 of 2000 complete in 157.7 sec
#  [---              10%                  ] 203 of 2000 complete in 158.3 sec
#  [---              10%                  ] 204 of 2000 complete in 158.8 sec
#  [---              10%                  ] 205 of 2000 complete in 159.4 sec
#  [---              10%                  ] 206 of 2000 complete in 160.0 sec
#  [---              10%                  ] 207 of 2000 complete in 161.2 sec
#  [---              10%                  ] 208 of 2000 complete in 162.3 sec
#  [---              10%                  ] 209 of 2000 complete in 162.9 sec
#  [---              10%                  ] 210 of 2000 complete in 163.5 sec
#  [----             10%                  ] 211 of 2000 complete in 164.1 sec
#  [----             10%                  ] 213 of 2000 complete in 165.3 sec
#  [----             10%                  ] 214 of 2000 complete in 165.8 sec
#  [----             10%                  ] 215 of 2000 complete in 166.4 sec
#  [----             10%                  ] 216 of 2000 complete in 167.0 sec
#  [----             10%                  ] 217 of 2000 complete in 167.6 sec
#  [----             10%                  ] 219 of 2000 complete in 169.0 sec
#  [----             11%                  ] 220 of 2000 complete in 170.1 sec
#  [----             11%                  ] 221 of 2000 complete in 171.2 sec
#  [----             11%                  ] 222 of 2000 complete in 172.4 sec
#  [----             11%                  ] 223 of 2000 complete in 173.0 sec
#  [----             11%                  ] 224 of 2000 complete in 175.2 sec
#  [----             11%                  ] 225 of 2000 complete in 176.3 sec
#  [----             11%                  ] 226 of 2000 complete in 177.5 sec
#  [----             11%                  ] 227 of 2000 complete in 178.6 sec
#  [----             11%                  ] 228 of 2000 complete in 179.7 sec
#  [----             11%                  ] 229 of 2000 complete in 180.3 sec
#  [----             11%                  ] 230 of 2000 complete in 180.8 sec
#  [----             11%                  ] 231 of 2000 complete in 181.4 sec
#  [----             11%                  ] 232 of 2000 complete in 182.5 sec
#  [----             11%                  ] 233 of 2000 complete in 183.7 sec
#  [----             11%                  ] 234 of 2000 complete in 184.8 sec
#  [----             11%                  ] 235 of 2000 complete in 185.3 sec
#  [----             11%                  ] 236 of 2000 complete in 185.9 sec
#  [----             11%                  ] 237 of 2000 complete in 186.5 sec
#  [----             11%                  ] 238 of 2000 complete in 187.6 sec
#  [----             11%                  ] 239 of 2000 complete in 188.7 sec
#  [----             12%                  ] 240 of 2000 complete in 189.3 sec
#  [----             12%                  ] 241 of 2000 complete in 189.8 sec
#  [----             12%                  ] 242 of 2000 complete in 190.4 sec
#  [----             12%                  ] 243 of 2000 complete in 191.5 sec
#  [----             12%                  ] 244 of 2000 complete in 192.7 sec
#  [----             12%                  ] 245 of 2000 complete in 193.8 sec
#  [----             12%                  ] 246 of 2000 complete in 194.9 sec
#  [----             12%                  ] 247 of 2000 complete in 196.0 sec
#  [----             12%                  ] 248 of 2000 complete in 196.6 sec
#  [----             12%                  ] 249 of 2000 complete in 197.2 sec
#  [----             12%                  ] 250 of 2000 complete in 197.7 sec
#  [----             12%                  ] 251 of 2000 complete in 198.3 sec
#  [----             12%                  ] 252 of 2000 complete in 198.8 sec
#  [----             12%                  ] 253 of 2000 complete in 199.4 sec
#  [----             12%                  ] 254 of 2000 complete in 199.9 sec
#  [----             12%                  ] 255 of 2000 complete in 200.5 sec
#  [----             12%                  ] 256 of 2000 complete in 201.6 sec
#  [----             12%                  ] 257 of 2000 complete in 202.1 sec
#  [----             12%                  ] 258 of 2000 complete in 202.7 sec
#  [----             13%                  ] 260 of 2000 complete in 203.6 sec
#  [----             13%                  ] 261 of 2000 complete in 204.2 sec
#  [----             13%                  ] 262 of 2000 complete in 204.7 sec
#  [----             13%                  ] 263 of 2000 complete in 205.3 sec
#  [-----            13%                  ] 264 of 2000 complete in 205.8 sec
#  [-----            13%                  ] 265 of 2000 complete in 206.4 sec
#  [-----            13%                  ] 266 of 2000 complete in 207.5 sec
#  [-----            13%                  ] 267 of 2000 complete in 208.6 sec
#  [-----            13%                  ] 268 of 2000 complete in 209.7 sec
#  [-----            13%                  ] 269 of 2000 complete in 210.8 sec
#  [-----            13%                  ] 270 of 2000 complete in 211.4 sec
#  [-----            13%                  ] 271 of 2000 complete in 212.0 sec
#  [-----            13%                  ] 272 of 2000 complete in 212.5 sec
#  [-----            13%                  ] 273 of 2000 complete in 213.1 sec
#  [-----            13%                  ] 275 of 2000 complete in 214.5 sec
#  [-----            13%                  ] 276 of 2000 complete in 215.6 sec
#  [-----            13%                  ] 277 of 2000 complete in 216.1 sec
#  [-----            13%                  ] 278 of 2000 complete in 216.7 sec
#  [-----            13%                  ] 279 of 2000 complete in 217.2 sec
#  [-----            14%                  ] 281 of 2000 complete in 218.1 sec
#  [-----            14%                  ] 282 of 2000 complete in 218.6 sec
#  [-----            14%                  ] 283 of 2000 complete in 219.7 sec
#  [-----            14%                  ] 284 of 2000 complete in 220.3 sec
#  [-----            14%                  ] 285 of 2000 complete in 220.8 sec
#  [-----            14%                  ] 286 of 2000 complete in 221.4 sec
#  [-----            14%                  ] 287 of 2000 complete in 222.0 sec
#  [-----            14%                  ] 288 of 2000 complete in 222.5 sec
#  [-----            14%                  ] 290 of 2000 complete in 223.1 sec
#  [-----            14%                  ] 292 of 2000 complete in 224.4 sec
#  [-----            14%                  ] 293 of 2000 complete in 225.0 sec
#  [-----            14%                  ] 294 of 2000 complete in 225.5 sec
#  [-----            14%                  ] 295 of 2000 complete in 226.1 sec
#  [-----            14%                  ] 296 of 2000 complete in 226.7 sec
#  [-----            14%                  ] 297 of 2000 complete in 227.8 sec
#  [-----            14%                  ] 298 of 2000 complete in 228.3 sec
#  [-----            14%                  ] 299 of 2000 complete in 228.9 sec
#  [-----            15%                  ] 300 of 2000 complete in 229.5 sec
#  [-----            15%                  ] 302 of 2000 complete in 230.3 sec
#  [-----            15%                  ] 303 of 2000 complete in 230.8 sec
#  [-----            15%                  ] 304 of 2000 complete in 231.4 sec
#  [-----            15%                  ] 305 of 2000 complete in 231.9 sec
#  [-----            15%                  ] 306 of 2000 complete in 232.5 sec
#  [-----            15%                  ] 307 of 2000 complete in 233.0 sec
#  [-----            15%                  ] 308 of 2000 complete in 234.2 sec
#  [-----            15%                  ] 309 of 2000 complete in 235.3 sec
#  [-----            15%                  ] 310 of 2000 complete in 235.9 sec
#  [-----            15%                  ] 311 of 2000 complete in 236.4 sec
#  [-----            15%                  ] 312 of 2000 complete in 237.0 sec
#  [-----            15%                  ] 314 of 2000 complete in 238.4 sec
#  [-----            15%                  ] 315 of 2000 complete in 238.9 sec
#  [------           15%                  ] 316 of 2000 complete in 239.5 sec
#  [------           15%                  ] 317 of 2000 complete in 240.1 sec
#  [------           15%                  ] 318 of 2000 complete in 241.2 sec
#  [------           15%                  ] 319 of 2000 complete in 241.7 sec
#  [------           16%                  ] 321 of 2000 complete in 243.3 sec
#  [------           16%                  ] 322 of 2000 complete in 244.4 sec
#  [------           16%                  ] 323 of 2000 complete in 245.5 sec
#  [------           16%                  ] 324 of 2000 complete in 246.1 sec
#  [------           16%                  ] 325 of 2000 complete in 246.6 sec
#  [------           16%                  ] 326 of 2000 complete in 247.2 sec
#  [------           16%                  ] 327 of 2000 complete in 247.7 sec
#  [------           16%                  ] 328 of 2000 complete in 248.3 sec
#  [------           16%                  ] 329 of 2000 complete in 248.8 sec
#  [------           16%                  ] 330 of 2000 complete in 249.4 sec
#  [------           16%                  ] 331 of 2000 complete in 250.0 sec
#  [------           16%                  ] 332 of 2000 complete in 250.5 sec
#  [------           16%                  ] 333 of 2000 complete in 251.1 sec
#  [------           16%                  ] 334 of 2000 complete in 251.6 sec
#  [------           16%                  ] 335 of 2000 complete in 252.2 sec
#  [------           16%                  ] 336 of 2000 complete in 252.7 sec
#  [------           16%                  ] 337 of 2000 complete in 253.3 sec
#  [------           16%                  ] 338 of 2000 complete in 253.8 sec
#  [------           16%                  ] 339 of 2000 complete in 254.4 sec
#  [------           17%                  ] 340 of 2000 complete in 255.0 sec
#  [------           17%                  ] 342 of 2000 complete in 255.5 sec
#  [------           17%                  ] 344 of 2000 complete in 256.1 sec
#  [------           17%                  ] 345 of 2000 complete in 256.6 sec
#  [------           17%                  ] 346 of 2000 complete in 257.2 sec
#  [------           17%                  ] 348 of 2000 complete in 257.7 sec
#  [------           17%                  ] 351 of 2000 complete in 258.6 sec
#  [------           17%                  ] 352 of 2000 complete in 259.2 sec
#  [------           17%                  ] 353 of 2000 complete in 259.7 sec
#  [------           17%                  ] 354 of 2000 complete in 260.3 sec
#  [------           17%                  ] 355 of 2000 complete in 260.8 sec
#  [------           17%                  ] 356 of 2000 complete in 261.4 sec
#  [------           17%                  ] 358 of 2000 complete in 263.0 sec
#  [------           17%                  ] 359 of 2000 complete in 264.1 sec
#  [------           18%                  ] 360 of 2000 complete in 264.7 sec
#  [------           18%                  ] 361 of 2000 complete in 265.2 sec
#  [------           18%                  ] 362 of 2000 complete in 265.8 sec
#  [------           18%                  ] 363 of 2000 complete in 266.3 sec
#  [------           18%                  ] 364 of 2000 complete in 266.9 sec
#  [------           18%                  ] 367 of 2000 complete in 267.9 sec
#  [------           18%                  ] 368 of 2000 complete in 268.4 sec
#  [-------          18%                  ] 369 of 2000 complete in 269.0 sec
#  [-------          18%                  ] 370 of 2000 complete in 269.5 sec
#  [-------          18%                  ] 371 of 2000 complete in 270.1 sec
#  [-------          18%                  ] 372 of 2000 complete in 270.6 sec
#  [-------          18%                  ] 373 of 2000 complete in 271.2 sec
#  [-------          18%                  ] 374 of 2000 complete in 271.8 sec
#  [-------          18%                  ] 375 of 2000 complete in 272.3 sec
#  [-------          18%                  ] 376 of 2000 complete in 272.9 sec
#  [-------          18%                  ] 377 of 2000 complete in 273.5 sec
#  [-------          18%                  ] 378 of 2000 complete in 274.0 sec
#  [-------          18%                  ] 379 of 2000 complete in 274.6 sec
#  [-------          19%                  ] 380 of 2000 complete in 275.1 sec
#  [-------          19%                  ] 381 of 2000 complete in 275.7 sec
#  [-------          19%                  ] 383 of 2000 complete in 276.3 sec
#  [-------          19%                  ] 384 of 2000 complete in 276.8 sec
#  [-------          19%                  ] 385 of 2000 complete in 277.4 sec
#  [-------          19%                  ] 386 of 2000 complete in 278.0 sec
#  [-------          19%                  ] 387 of 2000 complete in 278.6 sec
#  [-------          19%                  ] 388 of 2000 complete in 279.1 sec
#  [-------          19%                  ] 389 of 2000 complete in 279.7 sec
#  [-------          19%                  ] 390 of 2000 complete in 280.8 sec
#  [-------          19%                  ] 391 of 2000 complete in 281.4 sec
#  [-------          19%                  ] 392 of 2000 complete in 281.9 sec
#  [-------          19%                  ] 393 of 2000 complete in 282.5 sec
#  [-------          19%                  ] 395 of 2000 complete in 283.1 sec
#  [-------          19%                  ] 396 of 2000 complete in 283.6 sec
#  [-------          19%                  ] 397 of 2000 complete in 284.2 sec
#  [-------          19%                  ] 398 of 2000 complete in 284.7 sec
#  [-------          20%                  ] 400 of 2000 complete in 285.3 sec
#  [-------          20%                  ] 401 of 2000 complete in 285.8 sec
#  [-------          20%                  ] 402 of 2000 complete in 286.4 sec
#  [-------          20%                  ] 403 of 2000 complete in 287.0 sec
#  [-------          20%                  ] 404 of 2000 complete in 287.5 sec
#  [-------          20%                  ] 405 of 2000 complete in 288.1 sec
#  [-------          20%                  ] 406 of 2000 complete in 288.6 sec
#  [-------          20%                  ] 407 of 2000 complete in 289.2 sec
#  [-------          20%                  ] 408 of 2000 complete in 289.7 sec
#  [-------          20%                  ] 409 of 2000 complete in 290.3 sec
#  [-------          20%                  ] 411 of 2000 complete in 290.9 sec
#  [-------          20%                  ] 413 of 2000 complete in 291.7 sec
#  [-------          20%                  ] 414 of 2000 complete in 292.2 sec
#  [-------          20%                  ] 415 of 2000 complete in 292.8 sec
#  [-------          20%                  ] 416 of 2000 complete in 293.4 sec
#  [-------          20%                  ] 417 of 2000 complete in 294.5 sec
#  [-------          20%                  ] 418 of 2000 complete in 295.6 sec
#  [-------          20%                  ] 419 of 2000 complete in 296.1 sec
#  [-------          21%                  ] 420 of 2000 complete in 296.7 sec
#  [-------          21%                  ] 421 of 2000 complete in 297.2 sec
#  [--------         21%                  ] 422 of 2000 complete in 297.8 sec
#  [--------         21%                  ] 423 of 2000 complete in 298.3 sec
#  [--------         21%                  ] 424 of 2000 complete in 298.9 sec
#  [--------         21%                  ] 425 of 2000 complete in 299.5 sec
#  [--------         21%                  ] 426 of 2000 complete in 300.6 sec
#  [--------         21%                  ] 427 of 2000 complete in 301.1 sec
#  [--------         21%                  ] 428 of 2000 complete in 301.7 sec
#  [--------         21%                  ] 429 of 2000 complete in 302.2 sec
#  [--------         21%                  ] 430 of 2000 complete in 302.8 sec
#  [--------         21%                  ] 431 of 2000 complete in 303.4 sec
#  [--------         21%                  ] 432 of 2000 complete in 303.9 sec
#  [--------         21%                  ] 433 of 2000 complete in 304.5 sec
#  [--------         21%                  ] 435 of 2000 complete in 305.8 sec
#  [--------         21%                  ] 436 of 2000 complete in 307.0 sec
#  [--------         21%                  ] 437 of 2000 complete in 309.2 sec
#  [--------         21%                  ] 438 of 2000 complete in 310.3 sec
#  [--------         21%                  ] 439 of 2000 complete in 311.4 sec
#  [--------         22%                  ] 440 of 2000 complete in 312.5 sec
#  [--------         22%                  ] 441 of 2000 complete in 313.7 sec
#  [--------         22%                  ] 442 of 2000 complete in 314.8 sec
#  [--------         22%                  ] 443 of 2000 complete in 317.0 sec
#  [--------         22%                  ] 444 of 2000 complete in 318.1 sec
#  [--------         22%                  ] 445 of 2000 complete in 319.2 sec
#  [--------         22%                  ] 446 of 2000 complete in 320.3 sec
#  [--------         22%                  ] 447 of 2000 complete in 321.4 sec
#  [--------         22%                  ] 448 of 2000 complete in 322.5 sec
#  [--------         22%                  ] 449 of 2000 complete in 323.6 sec
#  [--------         22%                  ] 450 of 2000 complete in 324.8 sec
#  [--------         22%                  ] 451 of 2000 complete in 325.3 sec
#  [--------         22%                  ] 452 of 2000 complete in 326.4 sec
#  [--------         22%                  ] 453 of 2000 complete in 327.5 sec
#  [--------         22%                  ] 454 of 2000 complete in 328.1 sec
#  [--------         22%                  ] 455 of 2000 complete in 329.2 sec
#  [--------         22%                  ] 456 of 2000 complete in 330.3 sec
#  [--------         22%                  ] 457 of 2000 complete in 331.4 sec
#  [--------         22%                  ] 458 of 2000 complete in 332.6 sec
#  [--------         22%                  ] 459 of 2000 complete in 333.7 sec
#  [--------         23%                  ] 460 of 2000 complete in 334.2 sec
#  [--------         23%                  ] 461 of 2000 complete in 334.8 sec
#  [--------         23%                  ] 462 of 2000 complete in 335.3 sec
#  [--------         23%                  ] 463 of 2000 complete in 335.9 sec
#  [--------         23%                  ] 464 of 2000 complete in 336.4 sec
#  [--------         23%                  ] 465 of 2000 complete in 337.0 sec
#  [--------         23%                  ] 467 of 2000 complete in 338.3 sec
#  [--------         23%                  ] 468 of 2000 complete in 338.8 sec
#  [--------         23%                  ] 469 of 2000 complete in 339.4 sec
#  [--------         23%                  ] 470 of 2000 complete in 340.0 sec
#  [--------         23%                  ] 472 of 2000 complete in 341.5 sec
#  [--------         23%                  ] 473 of 2000 complete in 342.1 sec
#  [---------        23%                  ] 474 of 2000 complete in 342.6 sec
#  [---------        23%                  ] 475 of 2000 complete in 343.2 sec
#  [---------        23%                  ] 476 of 2000 complete in 344.3 sec
#  [---------        23%                  ] 477 of 2000 complete in 345.4 sec
#  [---------        23%                  ] 478 of 2000 complete in 346.0 sec
#  [---------        23%                  ] 479 of 2000 complete in 346.5 sec
#  [---------        24%                  ] 480 of 2000 complete in 347.6 sec
#  [---------        24%                  ] 481 of 2000 complete in 348.7 sec
#  [---------        24%                  ] 482 of 2000 complete in 349.9 sec
#  [---------        24%                  ] 483 of 2000 complete in 351.0 sec
#  [---------        24%                  ] 484 of 2000 complete in 351.5 sec
#  [---------        24%                  ] 485 of 2000 complete in 352.1 sec
#  [---------        24%                  ] 486 of 2000 complete in 352.6 sec
#  [---------        24%                  ] 487 of 2000 complete in 353.2 sec
#  [---------        24%                  ] 488 of 2000 complete in 353.7 sec
#  [---------        24%                  ] 489 of 2000 complete in 354.3 sec
#  [---------        24%                  ] 490 of 2000 complete in 354.9 sec
#  [---------        24%                  ] 491 of 2000 complete in 355.4 sec
#  [---------        24%                  ] 492 of 2000 complete in 356.0 sec
#  [---------        24%                  ] 493 of 2000 complete in 356.5 sec
#  [---------        24%                  ] 494 of 2000 complete in 357.1 sec
#  [---------        24%                  ] 496 of 2000 complete in 357.6 sec
#  [---------        24%                  ] 498 of 2000 complete in 358.5 sec
#  [---------        24%                  ] 499 of 2000 complete in 359.0 sec
#  [---------        25%                  ] 500 of 2000 complete in 359.6 sec
#  [---------        25%                  ] 502 of 2000 complete in 360.9 sec
#  [---------        25%                  ] 503 of 2000 complete in 361.4 sec
#  [---------        25%                  ] 504 of 2000 complete in 362.0 sec
#  [---------        25%                  ] 505 of 2000 complete in 362.5 sec
#  [---------        25%                  ] 506 of 2000 complete in 363.1 sec
#  [---------        25%                  ] 507 of 2000 complete in 363.6 sec
#  [---------        25%                  ] 508 of 2000 complete in 364.2 sec
#  [---------        25%                  ] 509 of 2000 complete in 364.8 sec
#  [---------        25%                  ] 510 of 2000 complete in 365.3 sec
#  [---------        25%                  ] 511 of 2000 complete in 365.9 sec
#  [---------        25%                  ] 513 of 2000 complete in 366.4 sec
#  [---------        25%                  ] 514 of 2000 complete in 367.0 sec
#  [---------        25%                  ] 516 of 2000 complete in 368.6 sec
#  [---------        25%                  ] 517 of 2000 complete in 369.7 sec
#  [---------        25%                  ] 518 of 2000 complete in 370.3 sec
#  [---------        25%                  ] 519 of 2000 complete in 370.8 sec
#  [---------        26%                  ] 520 of 2000 complete in 371.4 sec
#  [---------        26%                  ] 521 of 2000 complete in 372.0 sec
#  [---------        26%                  ] 522 of 2000 complete in 372.5 sec
#  [---------        26%                  ] 524 of 2000 complete in 373.1 sec
#  [---------        26%                  ] 525 of 2000 complete in 373.7 sec
#  [---------        26%                  ] 526 of 2000 complete in 374.2 sec
#  [----------       26%                  ] 528 of 2000 complete in 375.0 sec
#  [----------       26%                  ] 529 of 2000 complete in 375.6 sec
#  [----------       26%                  ] 530 of 2000 complete in 376.2 sec
#  [----------       26%                  ] 531 of 2000 complete in 376.7 sec
#  [----------       26%                  ] 532 of 2000 complete in 377.3 sec
#  [----------       26%                  ] 533 of 2000 complete in 377.8 sec
#  [----------       26%                  ] 534 of 2000 complete in 378.4 sec
#  [----------       26%                  ] 535 of 2000 complete in 378.9 sec
#  [----------       26%                  ] 537 of 2000 complete in 379.8 sec
#  [----------       26%                  ] 538 of 2000 complete in 380.3 sec
#  [----------       26%                  ] 539 of 2000 complete in 380.9 sec
#  [----------       27%                  ] 540 of 2000 complete in 381.5 sec
#  [----------       27%                  ] 541 of 2000 complete in 382.0 sec
#  [----------       27%                  ] 542 of 2000 complete in 382.6 sec
#  [----------       27%                  ] 543 of 2000 complete in 383.2 sec
#  [----------       27%                  ] 544 of 2000 complete in 383.7 sec
#  [----------       27%                  ] 545 of 2000 complete in 384.3 sec
#  [----------       27%                  ] 546 of 2000 complete in 384.9 sec
#  [----------       27%                  ] 547 of 2000 complete in 385.4 sec
#  [----------       27%                  ] 548 of 2000 complete in 386.0 sec
#  [----------       27%                  ] 549 of 2000 complete in 386.5 sec
#  [----------       27%                  ] 550 of 2000 complete in 387.1 sec
#  [----------       27%                  ] 551 of 2000 complete in 387.6 sec
#  [----------       27%                  ] 552 of 2000 complete in 388.2 sec
#  [----------       27%                  ] 553 of 2000 complete in 388.7 sec
#  [----------       27%                  ] 554 of 2000 complete in 389.3 sec
#  [----------       27%                  ] 555 of 2000 complete in 389.9 sec
#  [----------       27%                  ] 556 of 2000 complete in 390.4 sec
#  [----------       27%                  ] 557 of 2000 complete in 391.0 sec
#  [----------       27%                  ] 558 of 2000 complete in 391.5 sec
#  [----------       28%                  ] 560 of 2000 complete in 392.4 sec
#  [----------       28%                  ] 562 of 2000 complete in 393.2 sec
#  [----------       28%                  ] 563 of 2000 complete in 393.7 sec
#  [----------       28%                  ] 564 of 2000 complete in 394.3 sec
#  [----------       28%                  ] 565 of 2000 complete in 394.9 sec
#  [----------       28%                  ] 566 of 2000 complete in 395.4 sec
#  [----------       28%                  ] 567 of 2000 complete in 396.0 sec
#  [----------       28%                  ] 570 of 2000 complete in 397.0 sec
#  [----------       28%                  ] 571 of 2000 complete in 397.6 sec
#  [----------       28%                  ] 572 of 2000 complete in 398.1 sec
#  [----------       28%                  ] 574 of 2000 complete in 399.0 sec
#  [----------       28%                  ] 575 of 2000 complete in 399.5 sec
#  [----------       28%                  ] 576 of 2000 complete in 400.1 sec
#  [----------       28%                  ] 577 of 2000 complete in 400.6 sec
#  [----------       28%                  ] 578 of 2000 complete in 401.2 sec
#  [-----------      28%                  ] 579 of 2000 complete in 401.7 sec
#  [-----------      29%                  ] 581 of 2000 complete in 402.3 sec
#  [-----------      29%                  ] 583 of 2000 complete in 403.1 sec
#  [-----------      29%                  ] 584 of 2000 complete in 403.6 sec
#  [-----------      29%                  ] 586 of 2000 complete in 404.5 sec
#  [-----------      29%                  ] 587 of 2000 complete in 405.0 sec
#  [-----------      29%                  ] 588 of 2000 complete in 405.6 sec
#  [-----------      29%                  ] 589 of 2000 complete in 406.2 sec
#  [-----------      29%                  ] 590 of 2000 complete in 406.7 sec
#  [-----------      29%                  ] 591 of 2000 complete in 407.3 sec
#  [-----------      29%                  ] 592 of 2000 complete in 407.8 sec
#  [-----------      29%                  ] 593 of 2000 complete in 408.4 sec
#  [-----------      29%                  ] 594 of 2000 complete in 408.9 sec
#  [-----------      29%                  ] 596 of 2000 complete in 409.5 sec
#  [-----------      29%                  ] 597 of 2000 complete in 410.0 sec
#  [-----------      30%                  ] 600 of 2000 complete in 411.0 sec
#  [-----------      30%                  ] 601 of 2000 complete in 411.5 sec
#  [-----------      30%                  ] 602 of 2000 complete in 412.1 sec
#  [-----------      30%                  ] 603 of 2000 complete in 412.7 sec
#  [-----------      30%                  ] 604 of 2000 complete in 413.2 sec
#  [-----------      30%                  ] 605 of 2000 complete in 413.8 sec
#  [-----------      30%                  ] 606 of 2000 complete in 414.3 sec
#  [-----------      30%                  ] 608 of 2000 complete in 414.9 sec
#  [-----------      30%                  ] 609 of 2000 complete in 415.4 sec
#  [-----------      30%                  ] 611 of 2000 complete in 416.3 sec
#  [-----------      30%                  ] 613 of 2000 complete in 417.1 sec
#  [-----------      30%                  ] 614 of 2000 complete in 417.6 sec
#  [-----------      30%                  ] 615 of 2000 complete in 418.2 sec
#  [-----------      30%                  ] 617 of 2000 complete in 419.8 sec
#  [-----------      30%                  ] 618 of 2000 complete in 420.4 sec
#  [-----------      30%                  ] 619 of 2000 complete in 420.9 sec
#  [-----------      31%                  ] 620 of 2000 complete in 421.5 sec
#  [-----------      31%                  ] 621 of 2000 complete in 422.0 sec
#  [-----------      31%                  ] 622 of 2000 complete in 422.6 sec
#  [-----------      31%                  ] 623 of 2000 complete in 423.1 sec
#  [-----------      31%                  ] 624 of 2000 complete in 424.3 sec
#  [-----------      31%                  ] 625 of 2000 complete in 425.4 sec
#  [-----------      31%                  ] 626 of 2000 complete in 425.9 sec
#  [-----------      31%                  ] 627 of 2000 complete in 426.5 sec
#  [-----------      31%                  ] 628 of 2000 complete in 427.1 sec
#  [-----------      31%                  ] 629 of 2000 complete in 427.6 sec
#  [-----------      31%                  ] 630 of 2000 complete in 428.2 sec
#  [------------     31%                  ] 632 of 2000 complete in 429.0 sec
#  [------------     31%                  ] 633 of 2000 complete in 429.6 sec
#  [------------     31%                  ] 634 of 2000 complete in 430.1 sec
#  [------------     31%                  ] 635 of 2000 complete in 430.7 sec
#  [------------     31%                  ] 636 of 2000 complete in 431.8 sec
#  [------------     31%                  ] 637 of 2000 complete in 432.9 sec
#  [------------     31%                  ] 638 of 2000 complete in 433.5 sec
#  [------------     31%                  ] 639 of 2000 complete in 434.1 sec
#  [------------     32%                  ] 640 of 2000 complete in 434.7 sec
#  [------------     32%                  ] 641 of 2000 complete in 435.2 sec
#  [------------     32%                  ] 642 of 2000 complete in 435.8 sec
#  [------------     32%                  ] 643 of 2000 complete in 436.4 sec
#  [------------     32%                  ] 644 of 2000 complete in 437.5 sec
#  [------------     32%                  ] 645 of 2000 complete in 438.1 sec
#  [------------     32%                  ] 646 of 2000 complete in 438.6 sec
#  [------------     32%                  ] 647 of 2000 complete in 439.2 sec
#  [------------     32%                  ] 648 of 2000 complete in 439.8 sec
#  [------------     32%                  ] 649 of 2000 complete in 440.3 sec
#  [------------     32%                  ] 651 of 2000 complete in 441.1 sec
#  [------------     32%                  ] 652 of 2000 complete in 441.6 sec
#  [------------     32%                  ] 653 of 2000 complete in 442.2 sec
#  [------------     32%                  ] 654 of 2000 complete in 442.7 sec
#  [------------     32%                  ] 655 of 2000 complete in 443.3 sec
#  [------------     32%                  ] 656 of 2000 complete in 443.9 sec
#  [------------     32%                  ] 657 of 2000 complete in 444.4 sec
#  [------------     32%                  ] 658 of 2000 complete in 445.6 sec
#  [------------     32%                  ] 659 of 2000 complete in 446.1 sec
#  [------------     33%                  ] 660 of 2000 complete in 446.7 sec
#  [------------     33%                  ] 661 of 2000 complete in 447.2 sec
#  [------------     33%                  ] 662 of 2000 complete in 447.8 sec
#  [------------     33%                  ] 663 of 2000 complete in 448.3 sec
#  [------------     33%                  ] 664 of 2000 complete in 448.9 sec
#  [------------     33%                  ] 665 of 2000 complete in 449.5 sec
#  [------------     33%                  ] 666 of 2000 complete in 450.0 sec
#  [------------     33%                  ] 667 of 2000 complete in 450.6 sec
#  [------------     33%                  ] 668 of 2000 complete in 451.1 sec
#  [------------     33%                  ] 669 of 2000 complete in 451.7 sec
#  [------------     33%                  ] 670 of 2000 complete in 452.2 sec
#  [------------     33%                  ] 671 of 2000 complete in 452.8 sec
#  [------------     33%                  ] 672 of 2000 complete in 453.3 sec
#  [------------     33%                  ] 673 of 2000 complete in 453.9 sec
#  [------------     33%                  ] 674 of 2000 complete in 454.4 sec
#  [------------     33%                  ] 675 of 2000 complete in 455.0 sec
#  [------------     33%                  ] 676 of 2000 complete in 455.6 sec
#  [------------     33%                  ] 677 of 2000 complete in 456.1 sec
#  [------------     33%                  ] 678 of 2000 complete in 457.2 sec
#  [------------     33%                  ] 679 of 2000 complete in 458.3 sec
#  [------------     34%                  ] 680 of 2000 complete in 458.9 sec
#  [------------     34%                  ] 681 of 2000 complete in 459.4 sec
#  [------------     34%                  ] 682 of 2000 complete in 460.0 sec
#  [------------     34%                  ] 683 of 2000 complete in 460.6 sec
#  [------------     34%                  ] 684 of 2000 complete in 461.1 sec
#  [-------------    34%                  ] 685 of 2000 complete in 461.7 sec
#  [-------------    34%                  ] 686 of 2000 complete in 462.2 sec
#  [-------------    34%                  ] 687 of 2000 complete in 462.8 sec
#  [-------------    34%                  ] 688 of 2000 complete in 463.3 sec
#  [-------------    34%                  ] 689 of 2000 complete in 463.9 sec
#  [-------------    34%                  ] 690 of 2000 complete in 464.4 sec
#  [-------------    34%                  ] 691 of 2000 complete in 465.0 sec
#  [-------------    34%                  ] 692 of 2000 complete in 465.6 sec
#  [-------------    34%                  ] 693 of 2000 complete in 466.1 sec
#  [-------------    34%                  ] 694 of 2000 complete in 466.7 sec
#  [-------------    34%                  ] 695 of 2000 complete in 467.2 sec
#  [-------------    34%                  ] 696 of 2000 complete in 467.8 sec
#  [-------------    34%                  ] 697 of 2000 complete in 468.3 sec
#  [-------------    34%                  ] 698 of 2000 complete in 468.9 sec
#  [-------------    34%                  ] 699 of 2000 complete in 469.5 sec
#  [-------------    35%                  ] 700 of 2000 complete in 470.0 sec
#  [-------------    35%                  ] 701 of 2000 complete in 470.6 sec
#  [-------------    35%                  ] 702 of 2000 complete in 471.1 sec
#  [-------------    35%                  ] 703 of 2000 complete in 471.7 sec
#  [-------------    35%                  ] 705 of 2000 complete in 472.2 sec
#  [-------------    35%                  ] 706 of 2000 complete in 472.8 sec
#  [-------------    35%                  ] 708 of 2000 complete in 473.6 sec
#  [-------------    35%                  ] 709 of 2000 complete in 474.2 sec
#  [-------------    35%                  ] 710 of 2000 complete in 474.8 sec
#  [-------------    35%                  ] 711 of 2000 complete in 475.3 sec
#  [-------------    35%                  ] 712 of 2000 complete in 475.9 sec
#  [-------------    35%                  ] 714 of 2000 complete in 476.7 sec
#  [-------------    35%                  ] 716 of 2000 complete in 477.6 sec
#  [-------------    35%                  ] 717 of 2000 complete in 478.1 sec
#  [-------------    35%                  ] 718 of 2000 complete in 478.7 sec
#  [-------------    35%                  ] 719 of 2000 complete in 479.8 sec
#  [-------------    36%                  ] 720 of 2000 complete in 480.9 sec
#  [-------------    36%                  ] 721 of 2000 complete in 481.5 sec
#  [-------------    36%                  ] 722 of 2000 complete in 482.1 sec
#  [-------------    36%                  ] 723 of 2000 complete in 482.6 sec
#  [-------------    36%                  ] 724 of 2000 complete in 483.2 sec
#  [-------------    36%                  ] 725 of 2000 complete in 483.7 sec
#  [-------------    36%                  ] 726 of 2000 complete in 484.3 sec
#  [-------------    36%                  ] 728 of 2000 complete in 485.9 sec
#  [-------------    36%                  ] 729 of 2000 complete in 487.0 sec
#  [-------------    36%                  ] 730 of 2000 complete in 487.6 sec
#  [-------------    36%                  ] 731 of 2000 complete in 488.1 sec
#  [-------------    36%                  ] 732 of 2000 complete in 488.7 sec
#  [-------------    36%                  ] 733 of 2000 complete in 489.2 sec
#  [-------------    36%                  ] 735 of 2000 complete in 490.2 sec
#  [-------------    36%                  ] 736 of 2000 complete in 490.8 sec
#  [--------------   36%                  ] 737 of 2000 complete in 491.3 sec
# ...
#  [-----------------89%--------------    ] 1790 of 2000 complete in 1142.4 sec
#  [-----------------89%--------------    ] 1791 of 2000 complete in 1142.9 sec
#  [-----------------89%--------------    ] 1792 of 2000 complete in 1144.0 sec
#  [-----------------89%--------------    ] 1793 of 2000 complete in 1144.6 sec
#  [-----------------89%--------------    ] 1794 of 2000 complete in 1145.7 sec
#  [-----------------89%--------------    ] 1795 of 2000 complete in 1146.8 sec
#  [-----------------89%--------------    ] 1796 of 2000 complete in 1147.9 sec
#  [-----------------89%--------------    ] 1797 of 2000 complete in 1149.1 sec
#  [-----------------89%--------------    ] 1798 of 2000 complete in 1150.2 sec
#  [-----------------89%--------------    ] 1799 of 2000 complete in 1151.3 sec
#  [-----------------90%--------------    ] 1800 of 2000 complete in 1152.5 sec
#  [-----------------90%--------------    ] 1801 of 2000 complete in 1153.6 sec
#  [-----------------90%--------------    ] 1802 of 2000 complete in 1154.7 sec
#  [-----------------90%--------------    ] 1803 of 2000 complete in 1155.9 sec
#  [-----------------90%--------------    ] 1804 of 2000 complete in 1157.0 sec
#  [-----------------90%--------------    ] 1805 of 2000 complete in 1158.1 sec
#  [-----------------90%--------------    ] 1806 of 2000 complete in 1159.2 sec
#  [-----------------90%--------------    ] 1807 of 2000 complete in 1160.3 sec
#  [-----------------90%--------------    ] 1808 of 2000 complete in 1161.5 sec
#  [-----------------90%--------------    ] 1809 of 2000 complete in 1162.0 sec
#  [-----------------90%--------------    ] 1810 of 2000 complete in 1162.6 sec
#  [-----------------90%--------------    ] 1811 of 2000 complete in 1163.7 sec
#  [-----------------90%--------------    ] 1812 of 2000 complete in 1164.2 sec
#  [-----------------90%--------------    ] 1813 of 2000 complete in 1165.4 sec
#  [-----------------90%--------------    ] 1814 of 2000 complete in 1166.5 sec
#  [-----------------90%--------------    ] 1815 of 2000 complete in 1167.6 sec
#  [-----------------90%--------------    ] 1816 of 2000 complete in 1168.1 sec
#  [-----------------90%--------------    ] 1817 of 2000 complete in 1169.2 sec
#  [-----------------90%--------------    ] 1818 of 2000 complete in 1170.4 sec
#  [-----------------90%--------------    ] 1819 of 2000 complete in 1171.5 sec
#  [-----------------91%--------------    ] 1820 of 2000 complete in 1172.6 sec
#  [-----------------91%--------------    ] 1821 of 2000 complete in 1173.7 sec
#  [-----------------91%--------------    ] 1822 of 2000 complete in 1174.9 sec
#  [-----------------91%--------------    ] 1823 of 2000 complete in 1176.0 sec
#  [-----------------91%--------------    ] 1824 of 2000 complete in 1177.1 sec
#  [-----------------91%--------------    ] 1825 of 2000 complete in 1178.2 sec
#  [-----------------91%--------------    ] 1826 of 2000 complete in 1179.3 sec
#  [-----------------91%--------------    ] 1827 of 2000 complete in 1180.5 sec
#  [-----------------91%--------------    ] 1828 of 2000 complete in 1181.6 sec
#  [-----------------91%--------------    ] 1829 of 2000 complete in 1182.7 sec
#  [-----------------91%--------------    ] 1830 of 2000 complete in 1183.8 sec
#  [-----------------91%--------------    ] 1831 of 2000 complete in 1184.9 sec
#  [-----------------91%--------------    ] 1832 of 2000 complete in 1186.0 sec
#  [-----------------91%--------------    ] 1833 of 2000 complete in 1187.1 sec
#  [-----------------91%--------------    ] 1834 of 2000 complete in 1187.7 sec
#  [-----------------91%--------------    ] 1835 of 2000 complete in 1188.4 sec
#  [-----------------91%--------------    ] 1836 of 2000 complete in 1189.0 sec
#  [-----------------91%--------------    ] 1837 of 2000 complete in 1189.5 sec
#  [-----------------91%--------------    ] 1838 of 2000 complete in 1190.1 sec
#  [-----------------91%--------------    ] 1839 of 2000 complete in 1190.7 sec
#  [-----------------92%--------------    ] 1840 of 2000 complete in 1191.3 sec
#  [-----------------92%--------------    ] 1841 of 2000 complete in 1191.8 sec
#  [-----------------92%---------------   ] 1843 of 2000 complete in 1192.8 sec
#  [-----------------92%---------------   ] 1844 of 2000 complete in 1193.4 sec
#  [-----------------92%---------------   ] 1845 of 2000 complete in 1193.9 sec
#  [-----------------92%---------------   ] 1847 of 2000 complete in 1194.9 sec
#  [-----------------92%---------------   ] 1848 of 2000 complete in 1196.1 sec
#  [-----------------92%---------------   ] 1849 of 2000 complete in 1197.2 sec
#  [-----------------92%---------------   ] 1850 of 2000 complete in 1197.8 sec
#  [-----------------92%---------------   ] 1851 of 2000 complete in 1198.9 sec
#  [-----------------92%---------------   ] 1852 of 2000 complete in 1199.5 sec
#  [-----------------92%---------------   ] 1853 of 2000 complete in 1200.1 sec
#  [-----------------92%---------------   ] 1854 of 2000 complete in 1201.2 sec
#  [-----------------92%---------------   ] 1855 of 2000 complete in 1202.3 sec
#  [-----------------92%---------------   ] 1856 of 2000 complete in 1202.9 sec
#  [-----------------92%---------------   ] 1857 of 2000 complete in 1204.0 sec
#  [-----------------92%---------------   ] 1858 of 2000 complete in 1204.6 sec
#  [-----------------92%---------------   ] 1859 of 2000 complete in 1205.1 sec
#  [-----------------93%---------------   ] 1860 of 2000 complete in 1205.7 sec
#  [-----------------93%---------------   ] 1861 of 2000 complete in 1206.2 sec
#  [-----------------93%---------------   ] 1862 of 2000 complete in 1207.4 sec
#  [-----------------93%---------------   ] 1863 of 2000 complete in 1207.9 sec
#  [-----------------93%---------------   ] 1864 of 2000 complete in 1208.5 sec
#  [-----------------93%---------------   ] 1865 of 2000 complete in 1209.0 sec
#  [-----------------93%---------------   ] 1866 of 2000 complete in 1209.6 sec
#  [-----------------93%---------------   ] 1867 of 2000 complete in 1210.2 sec
#  [-----------------93%---------------   ] 1868 of 2000 complete in 1210.7 sec
#  [-----------------93%---------------   ] 1869 of 2000 complete in 1211.3 sec
#  [-----------------93%---------------   ] 1870 of 2000 complete in 1211.8 sec
#  [-----------------93%---------------   ] 1871 of 2000 complete in 1212.4 sec
#  [-----------------93%---------------   ] 1872 of 2000 complete in 1213.0 sec
#  [-----------------93%---------------   ] 1873 of 2000 complete in 1214.1 sec
#  [-----------------93%---------------   ] 1874 of 2000 complete in 1215.2 sec
#  [-----------------93%---------------   ] 1875 of 2000 complete in 1216.3 sec
#  [-----------------93%---------------   ] 1876 of 2000 complete in 1216.9 sec
#  [-----------------93%---------------   ] 1877 of 2000 complete in 1217.5 sec
#  [-----------------93%---------------   ] 1878 of 2000 complete in 1218.1 sec
#  [-----------------93%---------------   ] 1879 of 2000 complete in 1218.6 sec
#  [-----------------94%---------------   ] 1880 of 2000 complete in 1219.2 sec
#  [-----------------94%---------------   ] 1881 of 2000 complete in 1219.8 sec
#  [-----------------94%---------------   ] 1882 of 2000 complete in 1220.3 sec
#  [-----------------94%---------------   ] 1883 of 2000 complete in 1220.9 sec
#  [-----------------94%---------------   ] 1884 of 2000 complete in 1221.4 sec
#  [-----------------94%---------------   ] 1885 of 2000 complete in 1222.0 sec
#  [-----------------94%---------------   ] 1887 of 2000 complete in 1222.8 sec
#  [-----------------94%---------------   ] 1888 of 2000 complete in 1223.4 sec
#  [-----------------94%---------------   ] 1889 of 2000 complete in 1223.9 sec
#  [-----------------94%---------------   ] 1890 of 2000 complete in 1224.5 sec
#  [-----------------94%---------------   ] 1891 of 2000 complete in 1225.0 sec
#  [-----------------94%---------------   ] 1892 of 2000 complete in 1225.6 sec
#  [-----------------94%---------------   ] 1893 of 2000 complete in 1226.2 sec
#  [-----------------94%---------------   ] 1894 of 2000 complete in 1226.7 sec
#  [-----------------94%----------------  ] 1895 of 2000 complete in 1227.3 sec
#  [-----------------94%----------------  ] 1896 of 2000 complete in 1227.9 sec
#  [-----------------94%----------------  ] 1897 of 2000 complete in 1228.4 sec
#  [-----------------94%----------------  ] 1898 of 2000 complete in 1229.0 sec
#  [-----------------94%----------------  ] 1899 of 2000 complete in 1230.1 sec
#  [-----------------95%----------------  ] 1900 of 2000 complete in 1231.2 sec
#  [-----------------95%----------------  ] 1901 of 2000 complete in 1232.4 sec
#  [-----------------95%----------------  ] 1902 of 2000 complete in 1232.9 sec
#  [-----------------95%----------------  ] 1903 of 2000 complete in 1233.5 sec
#  [-----------------95%----------------  ] 1904 of 2000 complete in 1234.1 sec
#  [-----------------95%----------------  ] 1905 of 2000 complete in 1234.6 sec
#  [-----------------95%----------------  ] 1906 of 2000 complete in 1235.2 sec
#  [-----------------95%----------------  ] 1907 of 2000 complete in 1235.8 sec
#  [-----------------95%----------------  ] 1908 of 2000 complete in 1236.3 sec
#  [-----------------95%----------------  ] 1909 of 2000 complete in 1236.9 sec
#  [-----------------95%----------------  ] 1910 of 2000 complete in 1237.4 sec
#  [-----------------95%----------------  ] 1911 of 2000 complete in 1238.0 sec
#  [-----------------95%----------------  ] 1912 of 2000 complete in 1238.6 sec
#  [-----------------95%----------------  ] 1913 of 2000 complete in 1239.1 sec
#  [-----------------95%----------------  ] 1914 of 2000 complete in 1239.7 sec
#  [-----------------95%----------------  ] 1915 of 2000 complete in 1240.2 sec
#  [-----------------95%----------------  ] 1917 of 2000 complete in 1241.2 sec
#  [-----------------95%----------------  ] 1918 of 2000 complete in 1241.7 sec
#  [-----------------96%----------------  ] 1920 of 2000 complete in 1242.8 sec
#  [-----------------96%----------------  ] 1921 of 2000 complete in 1243.3 sec
#  [-----------------96%----------------  ] 1922 of 2000 complete in 1243.9 sec
#  [-----------------96%----------------  ] 1923 of 2000 complete in 1244.4 sec
#  [-----------------96%----------------  ] 1924 of 2000 complete in 1245.0 sec
#  [-----------------96%----------------  ] 1925 of 2000 complete in 1245.5 sec
#  [-----------------96%----------------  ] 1926 of 2000 complete in 1246.1 sec
#  [-----------------96%----------------  ] 1927 of 2000 complete in 1246.6 sec
#  [-----------------96%----------------  ] 1928 of 2000 complete in 1247.2 sec
#  [-----------------96%----------------  ] 1929 of 2000 complete in 1247.8 sec
#  [-----------------96%----------------  ] 1930 of 2000 complete in 1248.3 sec
#  [-----------------96%----------------  ] 1931 of 2000 complete in 1248.9 sec
#  [-----------------96%----------------  ] 1932 of 2000 complete in 1249.5 sec
#  [-----------------96%----------------  ] 1933 of 2000 complete in 1250.0 sec
#  [-----------------96%----------------  ] 1934 of 2000 complete in 1250.6 sec
#  [-----------------96%----------------  ] 1935 of 2000 complete in 1251.2 sec
#  [-----------------96%----------------  ] 1936 of 2000 complete in 1251.8 sec
#  [-----------------96%----------------  ] 1937 of 2000 complete in 1252.3 sec
#  [-----------------96%----------------  ] 1938 of 2000 complete in 1252.9 sec
#  [-----------------96%----------------  ] 1939 of 2000 complete in 1253.5 sec
#  [-----------------97%----------------  ] 1940 of 2000 complete in 1254.0 sec
#  [-----------------97%----------------  ] 1941 of 2000 complete in 1254.6 sec
#  [-----------------97%----------------  ] 1942 of 2000 complete in 1255.1 sec
#  [-----------------97%----------------  ] 1943 of 2000 complete in 1255.7 sec
#  [-----------------97%----------------  ] 1944 of 2000 complete in 1256.2 sec
#  [-----------------97%----------------  ] 1945 of 2000 complete in 1256.8 sec
#  [-----------------97%----------------  ] 1946 of 2000 complete in 1257.4 sec
#  [-----------------97%----------------  ] 1947 of 2000 complete in 1257.9 sec
#  [-----------------97%----------------- ] 1948 of 2000 complete in 1258.5 sec
#  [-----------------97%----------------- ] 1949 of 2000 complete in 1259.0 sec
#  [-----------------97%----------------- ] 1951 of 2000 complete in 1260.1 sec
#  [-----------------97%----------------- ] 1952 of 2000 complete in 1260.6 sec
#  [-----------------97%----------------- ] 1953 of 2000 complete in 1261.2 sec
#  [-----------------97%----------------- ] 1954 of 2000 complete in 1262.4 sec
#  [-----------------97%----------------- ] 1955 of 2000 complete in 1263.5 sec
#  [-----------------97%----------------- ] 1956 of 2000 complete in 1264.0 sec
#  [-----------------97%----------------- ] 1957 of 2000 complete in 1264.6 sec
#  [-----------------97%----------------- ] 1958 of 2000 complete in 1265.7 sec
#  [-----------------97%----------------- ] 1959 of 2000 complete in 1266.8 sec
#  [-----------------98%----------------- ] 1960 of 2000 complete in 1268.0 sec
#  [-----------------98%----------------- ] 1961 of 2000 complete in 1269.1 sec
#  [-----------------98%----------------- ] 1962 of 2000 complete in 1270.2 sec
#  [-----------------98%----------------- ] 1963 of 2000 complete in 1271.3 sec
#  [-----------------98%----------------- ] 1964 of 2000 complete in 1272.5 sec
#  [-----------------98%----------------- ] 1965 of 2000 complete in 1273.6 sec
#  [-----------------98%----------------- ] 1966 of 2000 complete in 1274.7 sec
#  [-----------------98%----------------- ] 1967 of 2000 complete in 1275.8 sec
#  [-----------------98%----------------- ] 1968 of 2000 complete in 1277.0 sec
#  [-----------------98%----------------- ] 1969 of 2000 complete in 1278.1 sec
#  [-----------------98%----------------- ] 1970 of 2000 complete in 1278.6 sec
#  [-----------------98%----------------- ] 1971 of 2000 complete in 1279.2 sec
#  [-----------------98%----------------- ] 1972 of 2000 complete in 1279.8 sec
#  [-----------------98%----------------- ] 1973 of 2000 complete in 1280.3 sec
#  [-----------------98%----------------- ] 1974 of 2000 complete in 1280.9 sec
#  [-----------------98%----------------- ] 1975 of 2000 complete in 1281.4 sec
#  [-----------------98%----------------- ] 1976 of 2000 complete in 1282.0 sec
#  [-----------------98%----------------- ] 1977 of 2000 complete in 1282.6 sec
#  [-----------------98%----------------- ] 1978 of 2000 complete in 1283.2 sec
#  [-----------------98%----------------- ] 1979 of 2000 complete in 1283.8 sec
#  [-----------------99%----------------- ] 1980 of 2000 complete in 1284.3 sec
#  [-----------------99%----------------- ] 1981 of 2000 complete in 1284.9 sec
#  [-----------------99%----------------- ] 1982 of 2000 complete in 1285.4 sec
#  [-----------------99%----------------- ] 1983 of 2000 complete in 1286.0 sec
#  [-----------------99%----------------- ] 1984 of 2000 complete in 1286.6 sec
#  [-----------------99%----------------- ] 1985 of 2000 complete in 1287.1 sec
#  [-----------------99%----------------- ] 1986 of 2000 complete in 1287.7 sec
#  [-----------------99%----------------- ] 1987 of 2000 complete in 1288.2 sec
#  [-----------------99%----------------- ] 1988 of 2000 complete in 1288.8 sec
#  [-----------------99%----------------- ] 1989 of 2000 complete in 1289.3 sec
#  [-----------------99%----------------- ] 1990 of 2000 complete in 1289.9 sec
#  [-----------------99%----------------- ] 1991 of 2000 complete in 1290.5 sec
#  [-----------------99%----------------- ] 1992 of 2000 complete in 1291.0 sec
#  [-----------------99%----------------- ] 1994 of 2000 complete in 1291.8 sec
#  [-----------------99%----------------- ] 1995 of 2000 complete in 1292.3 sec
#  [-----------------99%----------------- ] 1996 of 2000 complete in 1292.9 sec
#  [-----------------99%----------------- ] 1997 of 2000 complete in 1293.4 sec
#  [-----------------99%----------------- ] 1998 of 2000 complete in 1294.0 sec
#  [-----------------99%----------------- ] 1999 of 2000 complete in 1294.5 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 1295.1 sec
#  [-----------------100%-----------------] 2001 of 2000 complete in 1295.7 sec

# %%
plt.figure(figsize=(8, 60))
pm.forestplot(hm_trace, vars=['slope', 'intercept']);
