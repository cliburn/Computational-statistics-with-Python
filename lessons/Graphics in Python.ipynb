# %% [markdown]
# Graphics in Python
# ====
#
# An illustrtion of what can be done with varoius Python graphics packages. Some packages are not in Anaconda by default and need to be installed
#
# ```
# pip install mpld3
# pip install seaborn
# conda install basemap
# ```

# %%
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# Put some imports here for convenience

import os
import string
import statsmodels.api as sm
import scipy.stats as ss
import pandas as pd
import mpld3
from mpld3 import plugins
from scipy.io import netcdf
from mpl_toolkits.basemap import Basemap
from pandas.tools.plotting import scatter_matrix, andrews_curves, parallel_coordinates, radviz
import pandas.tools.rplot as rplot

# %% [markdown]
# ## Matplotlib
#
# This is probably the most widely used plotting toolkit. It is what is loaded when we start a notebook with the `--pylab=inline` argument. Matplotllib has two interfaces:
# * a functional API that mimics Matlab (pylab)
# * an object-oriented version (matplotlib.pyplot, typically aliased to plt)
#
# Several examples are adapted from <http://matplotlib.org/gallery.html>

# %% [markdown]
# ### Line graph

# %%
try:
    nile = pd.read_pickle('nile.pic')
except:
    nile = sm.datasets.get_rdataset('Nile')
    nile = pd.DataFrame(nile.data)
    nile.to_pickle('nile.pic')
    
window = 20
offset = nile.time[0] + 20
ma = pd.rolling_mean(nile.Nile, window)
mstd = pd.rolling_std(nile.Nile, window)
plt.plot(nile.time, nile.Nile, 'k')
plt.plot(offset+ma.index, ma, 'b')
plt.fill_between(offset+mstd.index, ma-2*mstd, ma+2*mstd, color='b', alpha=0.2)
xlabel('Year', fontsize=16)
ylabel('Flow', fontsize=16)
title('Annual flow of river Nile at Aswan', fontsize=16);

# %% [markdown]
# ### Bar chart

# %%
df = sm.datasets.longley.load_pandas().data

c = cm.get_cmap("jet", len(df))
cvals = c(np.arange(len(df)))
plt.bar(df['YEAR'], df['UNEMP'], align='center', alpha=0.5, color=cvals)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of unemployed ', fontsize=16)
plt.xlim([df['YEAR'].min()-1, df['YEAR'].max()+1]);

# %%
# Scatter plot

df = sm.datasets.longley.load_pandas().data
plt.scatter(df['YEAR'], df['UNEMP'], alpha=0.5, 
            s=200.0*df['ARMED']/max(df['ARMED']),
            c=df['GNP'], cmap=cm.jet)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of unemployed ', fontsize=16)
plt.xlim([df['YEAR'].min()-1, df['YEAR'].max()+1]);

# %% [markdown]
# ### Histogram

# %%
iqs = np.random.normal(100, 15, 1000)
plt.hist(iqs, bins=15, normed=True, histtype='step')
xlabel('Intelligence Quotient', fontsize=16)
ylabel('Density', fontsize=16);

# %% [markdown]
# ### Contour plot

# %%
x = linspace(-3.0, 3.0, 100) 
y = linspace(-3.0, 3.0, 100) 
X, Y = meshgrid(x, y) 
Z = exp(-(X**2 + Y**2)) + np.random.normal(0, 0.1, size=X.shape)
plt.contour(X, Y, Z)
plt.contourf(X, Y, Z, cmap=cm.coolwarm)
plt.colorbar();

# %% [markdown]
# ### Data interpolation for scatter plot

# %%
npts = 200
x = uniform(-2,2,npts)
y = uniform(-2,2,npts)
z = x*np.exp(-x**2-y**2)
xi = linspace(-2.1,2.1,100)
yi = linspace(-2.1,2.1,100)
# grid the data.
zi = griddata(x, y, z, xi, yi)
# contour the gridded data, plotting dots at the randomly spaced data points.
CS = plt.contour(xi,yi,zi,15,linewidths=0.5,colors='k')
CS = plt.contourf(xi,yi,zi,15,cmap=plt.cm.jet)
plt.colorbar() # draw colorbar
plt.scatter(x,y,marker='o',c='b',s=5)
plt.xlim(-2,2)
plt.ylim(-2,2);

# %% [markdown]
# ### Adding interactivity
#
# A brushing example - Mouse over a region - the brushed area will be highlighted in all panels simultaneously. Also, notice that a toolbar with tools for panninng, zooming, brushing and resetting (home icon) appear as you hover over the image.
#
# Example from <http://mpld3.github.io/notebooks/mpld3_demo.html>

# %%
import mpld3
from mpld3 import plugins

fig, ax = plt.subplots(3, 3, figsize=(6, 6))
fig.subplots_adjust(hspace=0.1, wspace=0.1)
ax = ax[::-1]

X = np.random.normal(size=(3, 100))
for i in range(3):
    for j in range(3):
        ax[i, j].xaxis.set_major_formatter(plt.NullFormatter())
        ax[i, j].yaxis.set_major_formatter(plt.NullFormatter())
        points = ax[i, j].scatter(X[j], X[i])
        
plugins.connect(fig, plugins.LinkedBrush(points))
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el5734545129956002063836241"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el5734545129956002063836241", {"height": 480.0, "id": "el573454512995600", "data": {"data01": [[1.2326363067146184, -1.6382686085173392, -0.12330806865346049], [-0.7555674355575551, 0.6200419275325783, 1.0660786165131106], [1.1335880848484499, -0.41914570842905097, 2.2483748802959718], [-0.1459891701205376, 0.8344472166197847, -0.32141574637330816], [-0.09987654427359827, -0.15818951365990605, -0.10818796379595534], [-1.1131587568008166, -1.0236350211849778, -0.4033531953864095], [0.22002564703351377, -1.3418358245252178, 2.1331761022336306], [0.9040451702960288, 0.36292257114919496, 1.7225642538129384], [-0.25349058287487036, -0.8801249380603182, 0.09850430675910593], [-0.8079871103194441, 1.364415518577249, 0.3501337483860976], [-0.8668289264035731, 1.4382709301738033, 0.24283252037408712], [-1.2212013491155496, -1.0684576399343786, 0.27079716786588537], [1.104753699078421, 0.9647335955019987, 0.15928604319426787], [1.4903184404878687, -1.4662054712619594, -1.2150836460914272], [-1.0685910971081598, 0.04257457622482499, 0.39051743457622495], [0.2324747708077075, 0.17245531009248125, -1.4048130110153614], [0.6219683840609607, 0.17550924392011522, 0.21768711975409086], [0.27859898526956456, -0.9631353789969866, 1.8926224587106057], [-1.685613441308281, 0.02389892198686446, -2.1553826056999257], [-0.618779635175999, 1.1102380876559301, 0.3292405727133829], [0.579395335604772, -0.2273498456988217, -0.4491077444865093], [0.11903851853930408, 1.2360341683494187, 0.25869847900932735], [0.45197861120681615, 0.6312331169277018, 1.6983528200437228], [-0.5802655061856447, -1.23867897131502, -0.8809884502344101], [-1.0211264916004474, 0.8845401053643289, 0.09410360582374028], [0.34034662354175954, 0.624739303399735, 0.9384777680059773], [2.386898486874564, -1.6147481901009917, -1.3302192471474072], [-0.4554127015371698, -1.3743503220279765, 2.366737036262823], [0.20052201650723975, 1.108436060961328, 1.0853485243214773], [-0.13721636205279722, 1.0693561684949178, -0.6638837371746237], [1.1832017217662834, -0.9016000487212295, -1.3809930450534273], [0.003928252424994148, 0.9896618921134137, 1.030690939995251], [-0.013541463471771351, 0.9998786433182149, 1.010711591243279], [0.2868106042202393, -0.06450470398984233, 0.3906867458968936], [0.4727053954381581, -0.35044880299587483, 1.55514793406454], [0.054350047160877546, 1.2454922907474857, 1.4835339228689306], [-0.04378405461408731, 0.4519111090015636, 0.15556327970185127], [0.815134266887856, -0.23355301556809496, 0.3395590752596207], [1.1902566025481747, -1.2034224146369579, 0.5869059444371139], [-0.27447377755886715, 0.5493345697176432, 0.12572193618319027], [1.3083202538460588, -0.2505365782936687, -0.4345574587500758], [0.06403201373300584, 1.4284379514657755, -0.3313736575800682], [1.5211726335164286, -0.5161585335966835, -1.3492036643545244], [-2.194680586597855, -0.2530134347037268, -0.1763887537644929], [-1.413077937700845, -0.7819393144482321, -1.6922783313155374], [1.7836341526025907, -0.08928176800817297, -0.10819259930597735], [1.216456717287238, -0.7985406569520112, 0.36882559361774236], [-0.036623491979206814, -0.25111128894526574, -2.088957700814932], [-1.8733245556585432, 0.37816981369890956, 0.2285575410153333], [-1.3516745356019806, -1.945878959310546, -0.4077139679024713], [0.9141399502665144, -0.558454384370955, -1.051354427053493], [0.8662406754938443, -0.00434112467551032, -0.653024124339276], [-0.1759301047904066, 0.6678759610335262, 0.09441057581714267], [-1.4771803738827851, -0.6765389100233734, -0.843833613762023], [1.1988907144098846, 0.15008724672168045, -0.7010826983185199], [-0.8298981326363697, -0.563673420699928, 0.7272055515469168], [0.842565002378426, 1.5888163433979505, -1.0783477365560308], [-1.6701327111544586, 0.040921415497151344, -0.6439453277886427], [0.9817816749461508, -0.8998720786254786, -1.1828419845398825], [-0.19701331870338487, 0.6756446373806596, -0.09326299284674626], [-2.9201534052729414, 0.2266690881890450 ...

# %% [markdown]
# ### Basemap
#
# Example below is from <https://github.com/koldunovn/python_for_geosciences>

# %%
datafile = 'air.sig995.2012.nc'
if not os.path.exists(datafile):
    # !wget ftp://ftp.cdc.noaa.gov/Datasets/ncep.reanalysis/surface/air.sig995.2012.nc
f = netcdf.netcdf_file(datafile)
air = f.variables['air']
lat = f.variables['lat'][:]
lon = f.variables['lon'][:]
lon2, lat2 = np.meshgrid(lon,lat)
air_c = ((air[:] * air.scale_factor) + air.add_offset) - 273.15

plt.jet()
fig = plt.figure(figsize=(15,7))
m = Basemap(projection='ortho',lat_0=45,lon_0=-100,resolution='l')
x, y = m(lon2, lat2)
m.fillcontinents(color='lightgrey',lake_color='white')
m.drawcoastlines()
m.drawparallels(np.arange(-80.,81.,20.))
m.drawmeridians(np.arange(-180.,181.,20.))
m.drawmapboundary(fill_color='white')
cs = m.contourf(x,y,air_c[0,:,:],20)
plt.colorbar()
plt.title('Monthly mean SAT');

# %% [markdown]
# ### 3D plots

# %%
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3, cmap=cm.jet)
cset = ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100);

# %% [markdown]
# ### The awesome XKCD plot

# %%
with plt.xkcd():
    xs = linspace(0, 4*pi)
    plt.plot(xs, sin(xs))
    plt.title('Whoo Hoo!!!');

# %% [markdown]
# ## Seaborn
#
# This new library is designed for statistical graphics. Note that `import seaborn` resets Matplotlib defaults to be more "R"-like. To get back Matplotlib style plots, call `matplotlib.rcdefaults() `

# %% [markdown]
# ### Plot combining KDE with rug/histogram

# %%
import seaborn as sns

random.seed(23)
xs = random.normal(0,1,100)

figure(figsize=(8,4))
sns.set_palette("hls")
plt.subplot(1,2,1)
sns.distplot(xs, hist=False, rug=True);
sns.set_palette("coolwarm")
plt.subplot(1,2,2)
sns.distplot(xs, hist=True);

# %% [markdown]
# ### Box and violin plots

# %%
try:
    df = pd.read_pickle('sleep.pic')
except:
    df = sm.datasets.get_rdataset('sleep').data
    df.to_pickle('sleep.pic')
subplot(1,2,1)
sns.boxplot(df.extra, df.group, color="pastel")
subplot(1,2,2)
sns.violinplot(df.extra, df.group, color="pastel");

# %% [markdown]
# ### 2D density plots

# %%
random.seed(23)
xs = np.random.multivariate_normal([0,0], eye(2), 100)
data = pd.DataFrame(xs, columns=("X", "Y"))
sns.jointplot("X", "Y", data, kind="kde", color='orange');

# %% [markdown]
# ### Linear model plots

# %%
rcParams['axes.labelsize'] = 24
df = sm.datasets.cancer.load_pandas().data
sns.lmplot("population", "cancer", df)
plt.xlim([0, df.population.max()])
plt.ylim([0, df.cancer.max()]);

# %% [markdown]
# ## Plotting with Pandas

# %%
# reset IPythonn notebook defaults from seaborn
matplotlib.rcdefaults()
matplotlib.rcParams.update({'font.size': 10, 'figure.figsize': (6.0, 4.0), 
                            'figure.facecolor': 'white', 'savefig.dpi': 72, 
                            'figure.subplot.bottom': 0.125, 
                            'figure.edgecolor': 'white'})

# %% [markdown]
# ### Basic plots

# %%
df = pd.DataFrame(rand( 6, 3), columns=['A', 'B', 'C'])
fig, axs = plt.subplots(1, 3, figsize=(10, 3))
df.plot(kind='bar', title='Bar', ax=axs[0]);
df.plot(kind='barh', stacked=True, title='Stacked bar', ax=axs[1]);
df.plot(kind='line', title='Line', ax=axs[2]);

# %% [markdown]
# ### More simple plots

# %%
ts = pd.Series(randn(1000), index=pd.date_range('1/1/2000', periods=1000))
df = pd.DataFrame(randn(1000, 4) + arange(4), index=ts.index, columns=list('ABCD'))

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 6))
df.boxplot(ax=axs[0,0], grid=True)
df.plot(kind='hexbin', x='A', y='B', gridsize=25, ax=axs[0,1])
df['A'].hist(ax=axs[1,0])
df.plot(kind='kde', ax=axs[1,1], xlim=[-5,10])
tight_layout()

# %% [markdown]
# ### Plotting time series

# %%
from pandas import Series, date_range

days = date_range('2014-07-01', periods=365, freq='D')
ts = Series(normal(10, 1, len(days)), index=days)

fig, axs = plt.subplots(2, 1, figsize=(8, 6))
ts.plot(ax=axs[0])
ts['2014-12-01':'2014-12-31'].plot(ax=axs[1]);

# %% [markdown]
# ### Scatter plot matrix

# %%
try:
    mtcars = pd.read_pickle('mtcars.pic')
except:
    mtcars = sm.datasets.get_rdataset('mtcars')
    mtcars = pd.DataFrame(mtcars.data)
    mtcars.to_pickle('mtcars.pic')
scatter_matrix(mtcars[[0,2,3,4,5]], alpha=0.3, figsize=(8, 8), diagonal='kde', marker='o');

# %% [markdown]
# ### Andrews and Parallel Coordinates plots

# %%
fig, axs = plt.subplots(2, 1, figsize=(8, 8))
try:
    iris = pd.read_pickle('iris.pic')
except:
    iris = sm.datasets.get_rdataset('iris')
    iris = pd.DataFrame(iris.data)
    iris.to_pickle('iris.pic')

parallel_coordinates(iris, 'Species', ax=axs[0], colormap=cm.gnuplot)
andrews_curves(iris, 'Species', ax=axs[1], colormap=cm.gnuplot);

# %% [markdown]
# ### Trellis plots

# %%
try:
    tips = pd.read_pickle('tips.pic')
except:
    tips = pd.read_csv('https://raw.github.com/vincentarelbundock/Rdatasets/master/csv/reshape2/tips.csv')
    tips.to_pickle('tips.pic')

plot = rplot.RPlot(tips, x='total_bill', y='tip')
plot.add(rplot.TrellisGrid(['sex', 'smoker']))
plot.add(rplot.GeomScatter())
plot.add(rplot.GeomPolyFit(degree=2))
plot.render(plt.gcf());

# %%
# %install_ext http://raw.github.com/jrjohansson/version_information/master/version_information.py
# Out:
# Installed version_information.py. To use it, type:
#   %load_ext version_information

# %%
# %load_ext version_information

# %version_information numpy, scipy, matplotlib, basemap, pandas, seaborn, mpld3, matplotlib
# Out:
# The version_information extension is already loaded. To reload it, use:
#   %reload_ext version_information
# Software versions
# Python 3.3.5 |Anaconda 2.0.0 (x86_64)| (default, Mar 10 2014, 11:22:25) [GCC 4.0.1 (Apple Inc. build 5493)]
# IPython 2.1.0
# OS posix [darwin]
# numpy 1.8.1
# scipy 0.14.0
# matplotlib 1.3.1
# basemap 1.0.7
# pandas 0.14.0
# seaborn 0.3.1
# mpld3 0.2
# matplotlib 1.3.1
# <tr><td colspan='2'>Fri Jun 06 10:49:35 2014 EDT</td></tr>
