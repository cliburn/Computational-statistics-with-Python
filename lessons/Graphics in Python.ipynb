# %% [markdown]
# Graphics in Python
# ====
#
# An illustrtion of what can be done with varoius Python graphics packages

# %%
# Put some imports here for convenience
# pip install mpld3
# pip install seaborn
# conda install basemap
import os
import string
import statsmodels.api as sm
import scipy.stats as ss
import pandas as pd
import mpld3
from mpld3 import plugins
from scipy.io import netcdf
from mpl_toolkits.basemap import Basemap
from pandas.tools.plotting import scatter_matrix, andrews_curves, parallel_coordinates, radviz
import pandas.tools.rplot as rplot
# Out:
# /Users/cliburn/anaconda/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %% [markdown]
# ## Matplotlib
#
# This is probably the most widely used plotting toolkit. It is what is loaded when we start a notebook with the `--pylab=inline` argument. Matplotllib has two interfaces:
# * a functional API that mimics Matlab (pylab)
# * an object-oriented version (matplotlib.pyplot, typically aliased to plt)
#
# Several examples are adapted from <http://matplotlib.org/gallery.html>

# %% [markdown]
# ### Line graph

# %%
try:
    nile = pd.read_pickle('nile.pic')
except:
    nile = sm.datasets.get_rdataset('Nile')
    nile = pd.DataFrame(nile.data)
    nile.to_pickle('nile.pic')
    
window = 20
offset = nile.time[0] + 20
ma = pd.rolling_mean(nile.Nile, window)
mstd = pd.rolling_std(nile.Nile, window)
plt.plot(nile.time, nile.Nile, 'k')
plt.plot(offset+ma.index, ma, 'b')
plt.fill_between(offset+mstd.index, ma-2*mstd, ma+2*mstd, color='b', alpha=0.2)
xlabel('Year', fontsize=16)
ylabel('Flow', fontsize=16)
title('Annual flow of river Nile at Aswan', fontsize=16);

# %% [markdown]
# ### Bar chart

# %%
df = sm.datasets.longley.load_pandas().data

c = cm.get_cmap("jet", len(df))
cvals = c(np.arange(len(df)))
plt.bar(df['YEAR'], df['UNEMP'], align='center', alpha=0.5, color=cvals)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of unemployed ', fontsize=16)
plt.xlim([df['YEAR'].min()-1, df['YEAR'].max()+1]);

# %%
# Scatter plot

df = sm.datasets.longley.load_pandas().data
plt.scatter(df['YEAR'], df['UNEMP'], alpha=0.5, 
            s=200.0*df['ARMED']/max(df['ARMED']),
            c=df['GNP'], cmap=cm.jet)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Number of unemployed ', fontsize=16)
plt.xlim([df['YEAR'].min()-1, df['YEAR'].max()+1]);

# %% [markdown]
# ### Histogram

# %%
iqs = np.random.normal(100, 15, 1000)
plt.hist(iqs, bins=15, normed=True, histtype='step')
xlabel('Intelligence Quotient', fontsize=16)
ylabel('Density', fontsize=16);

# %% [markdown]
# ### Contour plot

# %%
x = linspace(-3.0, 3.0, 100) 
y = linspace(-3.0, 3.0, 100) 
X, Y = meshgrid(x, y) 
Z = exp(-(X**2 + Y**2)) + np.random.normal(0, 0.1, size=X.shape)
plt.contour(X, Y, Z)
plt.contourf(X, Y, Z, cmap=cm.coolwarm)
plt.colorbar();

# %% [markdown]
# ### Data interpolation for scatter plot

# %%
npts = 200
x = uniform(-2,2,npts)
y = uniform(-2,2,npts)
z = x*np.exp(-x**2-y**2)
xi = linspace(-2.1,2.1,100)
yi = linspace(-2.1,2.1,100)
# grid the data.
zi = griddata(x, y, z, xi, yi)
# contour the gridded data, plotting dots at the randomly spaced data points.
CS = plt.contour(xi,yi,zi,15,linewidths=0.5,colors='k')
CS = plt.contourf(xi,yi,zi,15,cmap=plt.cm.jet)
plt.colorbar() # draw colorbar
plt.scatter(x,y,marker='o',c='b',s=5)
plt.xlim(-2,2)
plt.ylim(-2,2);

# %% [markdown]
# ### Adding interactivity
#
# A brushing example - Mouse over a region - the brushed area will be highlighted in all panels simultaneously. Also, notice that a toolbar with tools for panninng, zooming, brushing and resetting (home icon) appear as you hover over the image.
#
# Example from <http://mpld3.github.io/notebooks/mpld3_demo.html>

# %%
import mpld3
from mpld3 import plugins

fig, ax = plt.subplots(3, 3, figsize=(6, 6))
fig.subplots_adjust(hspace=0.1, wspace=0.1)
ax = ax[::-1]

X = np.random.normal(size=(3, 100))
for i in range(3):
    for j in range(3):
        ax[i, j].xaxis.set_major_formatter(plt.NullFormatter())
        ax[i, j].yaxis.set_major_formatter(plt.NullFormatter())
        points = ax[i, j].scatter(X[j], X[i])
        
plugins.connect(fig, plugins.LinkedBrush(points))
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el6602246720472484077542019"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el6602246720472484077542019", {"axes": [{"xlim": [-5.0, 3.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [], "zoomable": true, "images": [], "xdomain": [-5.0, 3.0], "ylim": [-3.0, 4.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": 10.0, "position": "bottom", "nticks": 9, "tickvalues": null}, {"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [], "markers": [], "id": "el660224673716176", "ydomain": [-3.0, 4.0], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [1.0], "offsets": "data01", "yindex": 1, "id": "el660224687877136", "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#0000FF"]}], "xscale": "linear", "bbox": [0.125, 0.65781250000000002, 0.2421875, 0.2421875]}, {"xlim": [-3.0, 3.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [], "zoomable": true, "images": [], "xdomain": [-3.0, 3.0], "ylim": [-3.0, 4.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [], "markers": [], "id": "el660224673937808", "ydomain": [-3.0, 4.0], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [1.0], "offsets": "data01", "yindex": 1, "id": "el660224687879184", "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 2, "alphas": [null], "facecolors": ["#0000FF"]}], "xscale": "linear", "bbox": [0.39140625000000001, 0.65781250000000002, 0.24218749999999994, 0.2421875]}, {"xlim": [-3.0, 4.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [], "zoomable": true, "images": [], "xdomain": [-3.0, 4.0], "ylim": [-3.0, 4.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "g ...

# %% [markdown]
# ### Basemap
#
# Example below is from <https://github.com/koldunovn/python_for_geosciences>

# %%
datafile = 'air.sig995.2012.nc'
if not os.path.exists(datafile):
    # !wget ftp://ftp.cdc.noaa.gov/Datasets/ncep.reanalysis/surface/air.sig995.2012.nc
f = netcdf.netcdf_file(datafile)
air = f.variables['air']
lat = f.variables['lat'][:]
lon = f.variables['lon'][:]
lon2, lat2 = np.meshgrid(lon,lat)
air_c = ((air[:] * air.scale_factor) + air.add_offset) - 273.15

plt.jet()
fig = plt.figure(figsize=(15,7))
m = Basemap(projection='ortho',lat_0=45,lon_0=-100,resolution='l')
x, y = m(lon2, lat2)
m.fillcontinents(color='lightgrey',lake_color='white')
m.drawcoastlines()
m.drawparallels(np.arange(-80.,81.,20.))
m.drawmeridians(np.arange(-180.,181.,20.))
m.drawmapboundary(fill_color='white')
cs = m.contourf(x,y,air_c[0,:,:],20)
plt.colorbar()
plt.title('Monthly mean SAT');

# %% [markdown]
# ### 3D plots

# %%
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3, cmap=cm.jet)
cset = ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100);

# %% [markdown]
# ### The awesome XKCD plot

# %%
with plt.xkcd():
    xs = linspace(0, 4*pi)
    plt.plot(xs, sin(xs))
    plt.title('Whoo Hoo!!!');

# %% [markdown]
# ## Seaborn
#
# This new library is designed for statistical graphics. Note that `import seaborn` resets Matplotlib defaults to be more "R"-like. To get back Matplotlib style plots, call `matplotlib.rcdefaults() `

# %% [markdown]
# ### Plot combining KDE with rug/histogram

# %%
import seaborn as sns

random.seed(23)
xs = random.normal(0,1,100)

figure(figsize=(8,4))
sns.set_palette("hls")
plt.subplot(1,2,1)
sns.distplot(xs, hist=False, rug=True);
sns.set_palette("coolwarm")
plt.subplot(1,2,2)
sns.distplot(xs, hist=True);

# %% [markdown]
# ### Box and violin plots

# %%
try:
    df = pd.read_pickle('sleep.pic')
except:
    df = sm.datasets.get_rdataset('sleep').data
    df.to_pickle('sleep.pic')
subplot(1,2,1)
sns.boxplot(df.extra, df.group, color="pastel")
subplot(1,2,2)
sns.violinplot(df.extra, df.group, color="pastel");

# %% [markdown]
# ### 2D density plots

# %%
random.seed(23)
xs = np.random.multivariate_normal([0,0], eye(2), 100)
data = pd.DataFrame(xs, columns=("X", "Y"))
sns.jointplot("X", "Y", data, kind="kde", color='orange');

# %% [markdown]
# ### Linear model plots

# %%
rcParams['axes.labelsize'] = 24
df = sm.datasets.cancer.load_pandas().data
sns.lmplot("population", "cancer", df)
plt.xlim([0, df.population.max()])
plt.ylim([0, df.cancer.max()]);

# %% [markdown]
# ## Plotting with Pandas

# %%
# reset IPythonn notebook defaults from seaborn
matplotlib.rcdefaults()
matplotlib.rcParams.update({'font.size': 10, 'figure.figsize': (6.0, 4.0), 
                            'figure.facecolor': 'white', 'savefig.dpi': 72, 
                            'figure.subplot.bottom': 0.125, 
                            'figure.edgecolor': 'white'})

# %% [markdown]
# ### Basic plots

# %%
df = pd.DataFrame(rand( 6, 3), columns=['A', 'B', 'C'])
fig, axs = plt.subplots(2, 2, figsize=(8, 6))
df.plot(kind='bar', ax=axs[0,0]);
df.plot(kind='barh', stacked=True, ax=axs[0,1]);
df.plot(kind='line', ax=axs[1,0]);
df.plot(kind='area', ax=axs[1,1]);

# %% [markdown]
# ### More simple plots

# %%
ts = pd.Series(randn(1000), index=pd.date_range('1/1/2000', periods=1000))
df = pd.DataFrame(randn(1000, 4) + arange(4), index=ts.index, columns=list('ABCD'))

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 6))
df.boxplot(ax=axs[0,0], grid=True,return_type='axes')
df.plot(kind='hexbin', x='A', y='B', gridsize=25, ax=axs[0,1])
df['A'].hist(ax=axs[1,0])
df.plot(kind='kde', ax=axs[1,1], xlim=[-5,10])
tight_layout()

# %% [markdown]
# ### Plotting time series

# %%
from pandas import Series, date_range

days = date_range('2014-07-01', periods=365, freq='D')
ts = Series(normal(10, 1, len(days)), index=days)

fig, axs = plt.subplots(2, 1, figsize=(8, 6))
ts.plot(ax=axs[0])
ts['2014-12-01':'2014-12-31'].plot(ax=axs[1]);

# %% [markdown]
# ### Scatter plot matrix

# %%
try:
    mtcars = pd.read_pickle('mtcars.pic')
except:
    mtcars = sm.datasets.get_rdataset('mtcars')
    mtcars = pd.DataFrame(mtcars.data)
    mtcars.to_pickle('mtcars.pic')
scatter_matrix(mtcars[[0,2,3,4,5]], alpha=0.3, figsize=(8, 8), diagonal='kde', marker='o');

# %% [markdown]
# ### Andrews and Parallel Coordinates plots

# %%
fig, axs = plt.subplots(2, 1, figsize=(8, 8))
try:
    iris = pd.read_pickle('iris.pic')
except:
    iris = sm.datasets.get_rdataset('iris')
    iris = pd.DataFrame(iris.data)
    iris.to_pickle('iris.pic')

parallel_coordinates(iris, 'Species', ax=axs[0], colormap=cm.gnuplot)
andrews_curves(iris, 'Species', ax=axs[1], colormap=cm.gnuplot);

# %% [markdown]
# ### Trellis plots

# %%
try:
    tips = pd.read_pickle('tips.pic')
except:
    tips = pd.read_csv('https://raw.github.com/vincentarelbundock/Rdatasets/master/csv/reshape2/tips.csv')
    tips.to_pickle('tips.pic')

plot = rplot.RPlot(tips, x='total_bill', y='tip')
plot.add(rplot.TrellisGrid(['sex', 'smoker']))
plot.add(rplot.GeomScatter())
plot.add(rplot.GeomPolyFit(degree=2))
plot.render(plt.gcf());
