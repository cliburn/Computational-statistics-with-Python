# %%
from __future__ import division
import os
import sys
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
# %precision 4
plt.style.use('ggplot')

# %%
np.set_printoptions(formatter={'float': lambda x: '%.3f' % x})

# %% [markdown]
# Outline
# ----
#
# ### Resampling
#
# - Sampling with and without replacement
# - Bootstrap
# - Jackknife
# - Cross validation and LOOCV
# - Permutation resampling
#
# ### Simulations
#
# - Design of experiments
# - Power from simulations
# - Hypothesis testing from simulations
# - Empirical CDF
# - Density estimation

# %% [markdown]
# ### Setting the random seed

# %%
np.random.seed(123)

# %% [markdown]
# Resampling
# ----

# %% [markdown]
# ### Sampling with and without replacement

# %% [markdown]
# #### Sampling with replacement

# %%
# Sampling is done with replacement by default
np.random.choice(4, 12)
# Out:
# array([2, 1, 2, 2, 0, 2, 2, 1, 3, 2, 3, 1])

# %%
# Probability weights can be given
np.random.choice(4, 12, p=[.4, .1, .1, .4])
# Out:
# array([3, 3, 1, 0, 0, 3, 1, 0, 0, 3, 0, 0])

# %%
x = np.random.randint(0, 10, (8, 12))
x
# Out:
# array([[7, 2, 4, 8, 0, 7, 9, 3, 4, 6, 1, 5],
#        [6, 2, 1, 8, 3, 5, 0, 2, 6, 2, 4, 4],
#        [6, 3, 0, 6, 4, 7, 6, 7, 1, 5, 7, 9],
#        [2, 4, 8, 1, 2, 1, 1, 3, 5, 9, 0, 8],
#        [1, 6, 3, 3, 5, 9, 7, 9, 2, 3, 3, 3],
#        [8, 6, 9, 7, 6, 3, 9, 6, 6, 6, 1, 3],
#        [4, 3, 1, 0, 5, 8, 6, 8, 9, 1, 0, 3],
#        [1, 3, 4, 7, 6, 1, 4, 3, 3, 7, 6, 8]])

# %%
# sampling individual elements
np.random.choice(x.ravel(), 12)
# Out:
# array([1, 2, 4, 7, 1, 2, 2, 6, 7, 3, 8, 4])

# %%
# sampling rows
idx = np.random.choice(x.shape[0], 4)
x[idx, :]
# Out:
# array([[4, 3, 1, 0, 5, 8, 6, 8, 9, 1, 0, 3],
#        [4, 3, 1, 0, 5, 8, 6, 8, 9, 1, 0, 3],
#        [6, 2, 1, 8, 3, 5, 0, 2, 6, 2, 4, 4],
#        [4, 3, 1, 0, 5, 8, 6, 8, 9, 1, 0, 3]])

# %%
# sampling columns
idx = np.random.choice(x.shape[1], 4)
x[:, idx]
# Out:
# array([[9, 4, 3, 1],
#        [0, 6, 2, 4],
#        [6, 1, 7, 7],
#        [1, 5, 3, 0],
#        [7, 2, 9, 3],
#        [9, 6, 6, 1],
#        [6, 9, 8, 0],
#        [4, 3, 3, 6]])

# %% [markdown]
# #### Sampling without replacement

# %%
# Give the argument replace=False
try:
    np.random.choice(4, 12, replace=False)
except ValueError, e:
    print e
# Out:
# Cannot take a larger sample than population when 'replace=False'

# %% [markdown]
# #### Random shuffling
#
# You will likely have used this for the stochastic gradient descent homework.

# %%
x
# Out:
# array([[7, 2, 4, 8, 0, 7, 9, 3, 4, 6, 1, 5],
#        [6, 2, 1, 8, 3, 5, 0, 2, 6, 2, 4, 4],
#        [6, 3, 0, 6, 4, 7, 6, 7, 1, 5, 7, 9],
#        [2, 4, 8, 1, 2, 1, 1, 3, 5, 9, 0, 8],
#        [1, 6, 3, 3, 5, 9, 7, 9, 2, 3, 3, 3],
#        [8, 6, 9, 7, 6, 3, 9, 6, 6, 6, 1, 3],
#        [4, 3, 1, 0, 5, 8, 6, 8, 9, 1, 0, 3],
#        [1, 3, 4, 7, 6, 1, 4, 3, 3, 7, 6, 8]])

# %%
# Shuffling occurs "in place" for efficiency
np.random.shuffle(x)
x
# Out:
# array([[7, 2, 4, 8, 0, 7, 9, 3, 4, 6, 1, 5],
#        [4, 3, 1, 0, 5, 8, 6, 8, 9, 1, 0, 3],
#        [8, 6, 9, 7, 6, 3, 9, 6, 6, 6, 1, 3],
#        [2, 4, 8, 1, 2, 1, 1, 3, 5, 9, 0, 8],
#        [6, 3, 0, 6, 4, 7, 6, 7, 1, 5, 7, 9],
#        [6, 2, 1, 8, 3, 5, 0, 2, 6, 2, 4, 4],
#        [1, 3, 4, 7, 6, 1, 4, 3, 3, 7, 6, 8],
#        [1, 6, 3, 3, 5, 9, 7, 9, 2, 3, 3, 3]])

# %%
# To shuffle columns instead, transpose before shuffling
np.random.shuffle(x.T)
x
# Out:
# array([[7, 0, 4, 7, 9, 8, 1, 6, 4, 3, 2, 5],
#        [8, 5, 1, 4, 6, 0, 0, 1, 9, 8, 3, 3],
#        [3, 6, 9, 8, 9, 7, 1, 6, 6, 6, 6, 3],
#        [1, 2, 8, 2, 1, 1, 0, 9, 5, 3, 4, 8],
#        [7, 4, 0, 6, 6, 6, 7, 5, 1, 7, 3, 9],
#        [5, 3, 1, 6, 0, 8, 4, 2, 6, 2, 2, 4],
#        [1, 6, 4, 1, 4, 7, 6, 7, 3, 3, 3, 8],
#        [9, 5, 3, 1, 7, 3, 3, 3, 2, 9, 6, 3]])

# %%
# numpy.random.permutation does the same thing but returns a copy
np.random.permutation(x)
# Out:
# array([[7, 0, 4, 7, 9, 8, 1, 6, 4, 3, 2, 5],
#        [1, 6, 4, 1, 4, 7, 6, 7, 3, 3, 3, 8],
#        [1, 2, 8, 2, 1, 1, 0, 9, 5, 3, 4, 8],
#        [7, 4, 0, 6, 6, 6, 7, 5, 1, 7, 3, 9],
#        [9, 5, 3, 1, 7, 3, 3, 3, 2, 9, 6, 3],
#        [3, 6, 9, 8, 9, 7, 1, 6, 6, 6, 6, 3],
#        [8, 5, 1, 4, 6, 0, 0, 1, 9, 8, 3, 3],
#        [5, 3, 1, 6, 0, 8, 4, 2, 6, 2, 2, 4]])

# %%
# When given an integre n, permutation treats is as the array arange(n)
np.random.permutation(10)
# Out:
# array([4, 0, 6, 7, 5, 1, 8, 2, 3, 9])

# %%
# Use indices if you needed to shuffle collections of arrays in synchrony
x = np.arange(12).reshape(4,3)
y = x + 10
idx = np.random.permutation(x.shape[0])
print x[idx, :], '\n'
print y[idx, :]
# Out:
# [[ 9 10 11]
#  [ 3  4  5]
#  [ 6  7  8]
#  [ 0  1  2]]
#
# [[19 20 21]
#  [13 14 15]
#  [16 17 18]
#  [10 11 12]]

# %% [markdown]
# ### Bootstrap
#
# The bootstrap is commonly used to estimate statistics when theory fails. We have already seen the bootstrap for estiamting confidence bounds for convergence in the Monte Carlo integration.

# %%
# For example, what is the 95% confidence interval for 
# the mean of this data set if you didn't know how it was generated?

x = np.concatenate([np.random.exponential(size=200), np.random.normal(size=100)])
plt.hist(x, 25, histtype='step');

# %%
n = len(x)
reps = 10000
xb = np.random.choice(x, (n, reps))
mb = xb.mean(axis=0)
mb.sort()

np.percentile(mb, [2.5, 97.5])
# Out:
# array([0.483, 0.740])

# %% [markdown]
# #### Reprise of bootstrap example for Monte Carlo integration

# %%
def f(x):
    return x * np.cos(71*x) + np.sin(13*x)

# %%
# data sample for integration
n = 100
x = f(np.random.random(n))

# %%
# bootstrap MC integration
reps = 1000
xb = np.random.choice(x, (n, reps), replace=True)
yb = 1/np.arange(1, n+1)[:, None] * np.cumsum(xb, axis=0)
upper, lower = np.percentile(yb, [2.5, 97.5], axis=1)

# %%
plt.plot(np.arange(1, n+1)[:, None], yb, c='grey', alpha=0.02)
plt.plot(np.arange(1, n+1), yb[:, 0], c='red', linewidth=1)
plt.plot(np.arange(1, n+1), upper, 'b', np.arange(1, n+1), lower, 'b');

# %% [markdown]
# ### Leave some-out resampling

# %% [markdown]
# #### Jackknife estimate of parameters
#
# This shows the leave-one-out calculation idiom for Python. Unlike R, a -k index to an array does not delete the kth entry, but returns the kth entry from the end, so we need another way to efficiently drop one scalar or vector. This can be done using Boolean indexing as shown in the examples below, and is efficient since the operations are on *views* of the origianl array rather thna *copies*.

# %%
def jackknife(x, func):
    """Jackknife estimate of the estimator func"""
    n = len(x)
    idx = np.arange(n)
    return np.sum(func(x[idx!=i]) for i in range(n))/float(n)

# %%
# Jackknife estimate of standard deviation
x = np.random.normal(0, 2, 100)
jackknife(x, np.std)
# Out:
# 1.9223

# %%
def jackknife_var(x, func):
    """Jackknife estiamte of the variance of the estimator func."""
    n = len(x)
    idx = np.arange(n)
    j_est = jackknife(x, func)
    return (n-1)/(n + 0.0) * np.sum((func(x[idx!=i]) - j_est)**2.0 
                                    for i in range(n))

# %%
# estimate of the variance of an estimator 
jackknife_var(x, np.std)
# Out:
# 0.0254

# %% [markdown]
# #### Leave one out cross validation (LOOCV)
#
# LOOCV also uses the same idiom, and a simple example of LOOCV for model selection is illustrated.

# %%
a, b, c = 1, 2, 3
x = np.linspace(0, 5, 10)
y = a*x**2 + b*x + c + np.random.normal(0, 1, len(x))

# %%
plt.figure(figsize=(12,4))
for deg in range(1, 5):
    plt.subplot(1, 4, deg)
    beta = np.polyfit(x, y, deg)
    plt.plot(x, y, 'r:o')
    plt.plot(x, np.polyval(beta, x), 'b-')
    plt.title('Degree = %d' % deg)

# %%
def loocv(x, y, fit, pred, deg):
    """LOOCV RSS for fitting a polynomial model."""
    n = len(x)
    idx = np.arange(n)
    rss = np.sum([(y - pred(fit(x[idx!=i], y[idx!=i], deg), x))**2.0 for i in range(n)])
    return rss

# %%
# RSS does not detect overfitting and selects the most complex model
for deg in range(1, 5):
    print 'Degree = %d, RSS=%.2f' % (deg, np.sum((y - np.polyval(np.polyfit(x, y, deg), x))**2.0))
# Out:
# Degree = 1, RSS=59.90
# Degree = 2, RSS=6.20
# Degree = 3, RSS=6.20
# Degree = 4, RSS=6.20

# %%
# LOOCV selects the correct model
for deg in range(1, 5):
    print 'Degree = %d, RSS=%.2f' % (deg, loocv(x, y, np.polyfit, np.polyval, deg))
# Out:
# Degree = 1, RSS=628.41
# Degree = 2, RSS=64.35
# Degree = 3, RSS=67.81
# Degree = 4, RSS=85.39

# %% [markdown]
# ### Permutation resampling

# %% [markdown]
# #### For flexible hypothesis testing
#
# Suppose you have 2 data sets from unknown distribution and you want to test if some arbitrary statistic (e.g 7th percentile) is the same in the 2 data sets - what can you do?
#
# An appropirate test statistic is the difference between the 7th percentile, and if we knew the null distribution of this statisic, we could test for the null hypothesis that the statistic = 0. Permuting the labels of the 2 data sets allows us to create the empirical null distribution.

# %%
x = np.concatenate([np.random.exponential(size=200), 
                    np.random.normal(0, 1, size=100)])
y = np.concatenate([np.random.exponential(size=250), 
                    np.random.normal(0, 1, size=50)])

# %%
n1, n2 = map(len, (x, y))
reps = 10000

data = np.concatenate([x, y])
ps = np.array([np.random.permutation(n1+n2) for i in range(reps)])

# %%
xp = data[ps[:, :n1]]
yp = data[ps[:, n1:]]
samples = np.percentile(xp, 7, axis=1) - np.percentile(yp, 7, axis=1)

# %%
plt.hist(samples, 25, histtype='step')
test_stat = np.percentile(x, 7) - np.percentile(y, 7)
plt.axvline(test_stat)
plt.axvline(np.percentile(samples, 2.5), linestyle='--')
plt.axvline(np.percentile(samples, 97.5), linestyle='--')
print "p-value =", 2*np.sum(samples >= np.abs(test_stat))/reps
# Out:
# p-value = 0.0296

# %% [markdown]
# #### To correct for multipe comparisons in the presence of correlations

# %%
n = 1000 # 1000 genes
r = np.random.uniform(0, 1, (n,1))
sigma = r.dot(r.T)
sigma = np.eye(n)
mu_ctrls = np.zeros(n)

mu_cases = np.zeros(n)
hits = np.random.choice(n, n//10, replace=False)
mu_cases[hits] = 1
print hits
# Out:
# [616 144 606 170 828 573  49 469 249 506 388 841 189 453 182 126 958 229
#   46 571 971 261  86 956 136 402 739  10 125 568 332 785 884 599 620 344
#  404 677 771 570 672 145  18 488 611 580 688 206 345 151 864 635 644 539
#  582 593 619 382 969 955 631 760 536 305  95 962 450 465 545 972 855 825
#  697   1 796 558 613 834 312 291 311 452  74 515 254  98 445 205 783  27
#  709 364 923 811 935 925 974 549 340 247]

# %%
nsamples = 50
ctrls = np.random.multivariate_normal(mu_ctrls, sigma, nsamples)
cases = np.random.multivariate_normal(mu_cases, sigma, nsamples)

# %%
vmin = min(ctrls.min(), cases.min())
vmax = max(ctrls.max(), cases.max())

plt.subplot(121)
plt.imshow(ctrls, extent=[0, 1, 0, 2], interpolation='nearest', 
           vmin=vmin, vmax=vmax, cmap='jet')
plt.xticks([])
plt.yticks([])
plt.title('Controls')
plt.subplot(122)
plt.imshow(cases, extent=[0, 1, 0, 2], interpolation='nearest', 
           vmin=vmin, vmax=vmax, cmap='jet')
plt.xticks([])
plt.yticks([])
plt.title('Cases')
plt.colorbar();

# %%
from scipy.stats import ttest_ind

test_stat = ttest_ind(ctrls, cases, axis=0)

# %%
data = np.concatenate([ctrls, cases])

reps = 500
ps = np.array([np.random.permutation(nsamples+nsamples) for i in range(reps)])
pctrls = data[ps[:, :nsamples], :]
pcases = data[ps[:, nsamples:], :]

# %%
pctrls.shape
# Out:
# (500, 50, 1000)

# %%
tstats = ttest_ind(pctrls, pcases, axis=1)

# %%
(tstats[1] < 0.05).sum(axis=1)
# Out:
# array([50, 52, 65, 40, 53, 43, 42, 53, 48, 57, 57, 44, 48, 55, 49, 50, 55,
#        49, 52, 51, 43, 51, 52, 60, 43, 52, 47, 47, 55, 55, 70, 53, 53, 51,
#        50, 47, 56, 39, 51, 54, 60, 48, 59, 46, 54, 45, 56, 45, 49, 51, 46,
#        41, 62, 37, 47, 40, 47, 53, 55, 59, 60, 47, 32, 34, 55, 53, 55, 35,
#        43, 50, 40, 64, 56, 77, 54, 60, 45, 52, 57, 52, 53, 63, 47, 46, 46,
#        54, 58, 54, 50, 55, 47, 68, 48, 49, 45, 46, 43, 43, 50, 45, 47, 47,
#        41, 44, 37, 62, 32, 39, 47, 36, 51, 58, 51, 57, 44, 46, 54, 51, 48,
#        51, 44, 47, 55, 53, 51, 50, 50, 54, 41, 50, 42, 55, 49, 40, 61, 48,
#        41, 38, 51, 34, 52, 69, 52, 44, 54, 48, 48, 53, 45, 56, 53, 58, 47,
#        44, 41, 52, 49, 59, 45, 70, 41, 51, 52, 51, 50, 52, 56, 51, 52, 62,
#        42, 40, 51, 59, 56, 52, 51, 41, 53, 49, 42, 45, 47, 62, 46, 40, 41,
#        38, 40, 58, 58, 57, 55, 51, 48, 49, 47, 40, 47, 50, 65, 45, 46, 48,
#        46, 55, 44, 41, 62, 58, 55, 43, 48, 57, 53, 44, 41, 44, 50, 43, 46,
#        38, 46, 52, 55, 55, 37, 57, 30, 38, 60, 46, 50, 49, 54, 47, 49, 41,
#        37, 42, 46, 62, 48, 43, 55, 44, 53, 49, 48, 47, 52, 46, 70, 59, 48,
#        49, 41, 59, 50, 39, 55, 50, 49, 50, 44, 52, 54, 56, 51, 46, 49, 49,
#        47, 44, 52, 51, 52, 46, 45, 59, 41, 46, 40, 43, 83, 47, 42, 46, 53,
#        41, 42, 45, 67, 45, 43, 47, 54, 61, 47, 72, 41, 49, 46, 56, 60, 44,
#        47, 49, 42, 51, 55, 58, 40, 50, 56, 34, 37, 49, 43, 57, 42, 40, 46,
#        46, 41, 51, 55, 59, 52, 52, 42, 48, 56, 48, 39, 59, 46, 49, 44, 57,
#        40, 51, 47, 56, 42, 54, 50, 67, 51, 58, 54, 54, 50, 51, 49, 43, 39,
#        50, 60, 53, 38, 50, 54, 50, 45, 47, 53, 49, 56, 62, 55, 53, 57, 43,
#        52, 45, 38, 59, 52, 52, 41, 50, 46, 43, 45, 51, 54, 48, 45, 62, 50,
#        55, 65, 48, 42, 45, 53, 58, 59, 63, 50, 50, 62, 46, 50, 53, 53, 54,
#        47, 47, 38, 60, 45, 47, 48, 42, 53, 46, 53, 44, 56, 60, 63, 60, 63,
#        52, 45, 51, 38, 46, 50, 54, 62, 33, 54, 67, 54, 51, 57, 53, 51, 55,
#        48, 32, 43, 44, 60, 43, 69, 57, 49, 46, 55, 45, 48, 45, 71, 60, 36,
#        42, 48, 44, 47, 51, 49, 49, 60, 59, 54, 53, 43, 47, 67, 55, 52, 58,
#        50, 51, 39, 44, 38, 61, 44, 42, 41, 46, 49, 49, 45, 50, 59, 36, 53,
#        48, 54, 60, 68, 53, 60, 40])

# %% [markdown]
# Multiple testing
# ----

# %%
import pandas.rpy.common as com

# %%
com.importr('multcomp')
com.load_data('adevent')
# Out:
#            E1        E2        E3        E4        E5        E6        E7  \
# 1    no event  no event  no event  no event  no event  no event  no event
# 2    no event  no event  no event  no event  no event  no event  no event
# 3    no event  no event  no event  no event  no event  no event  no event
# 4    no event  no event  no event  no event  no event  no event  no event
# 5    no event  no event  no event  no event  no event  no event  no event
# 6    no event  no event  no event  no event  no event  no event  no event
# 7    no event  no event  no event  no event  no event  no event  no event
# 8    no event  no event  no event  no event  no event  no event  no event
# 9    no event  no event  no event  no event  no event  no event  no event
# 10   no event  no event  no event  no event  no event  no event  no event
# 11   no event  no event  no event  no event  no event  no event  no event
# 12   no event     event     event  no event  no event  no event  no event
# 13   no event  no event  no event  no event  no event  no event  no event
# 14   no event  no event  no event  no event  no event  no event  no event
# 15   no event  no event  no event  no event  no event  no event  no event
# 16   no event  no event  no event  no event  no event  no event  no event
# 17   no event  no event  no event  no event  no event  no event  no event
# 18   no event     event  no event  no event  no event  no event  no event
# 19   no event  no event  no event     event  no event  no event  no event
# 20      event  no event     event  no event  no event  no event  no event
# 21   no event  no event  no event  no event  no event  no event  no event
# 22      event  no event  no event  no event  no event  no event  no event
# 23   no event  no event  no event  no event  no event  no event  no event
# 24   no event     event     event  no event  no event  no event  no event
# 25   no event     event  no event  no event  no event  no event  no event
# 26   no event  no event  no event  no event  no event  no event  no event
# 27   no event  no event  no event  no event  no event  no event  no event
# 28      event  no event  no event  no event  no event  no event  no event
# 29   no event     event  no event  no event  no event  no event  no event
# 30      event  no event  no event  no event  no event  no event  no event
# ..        ...       ...       ...       ...       ...       ...       ...
# 131     event  no event  no event  no event  no event  no event  no event
# 132  no event  no event  no event  no event  no event  no event  no event
# 133     event  no event  no event  no event  no event     event  no event
# 134     event  no event     event  no event  no event  no event  no event
# 135     event  no event  no event  no event  no event     event  no event
# 136  no event  no event  no event  no event  no event  no event  no event
# 137  no event     event  no event  no event  no event  no event  no event
# 138     event  no event  no event     event  no event  no event  no event
# 139     event     event  no event  no event  no event  no event  no event
# 140  no event  no event  no event  no event  no event  no event  no event
# 141  no event  no event  no event  no event  no event  no event  no event
# 142     event  no event  no event  no event  no event  no event  no event
# 143     event  no event  no event     event  no event  no event  no event
# 144     event     event  no event  no event  no event  no event  no event
# 145  no event  no event  no event  no event  no event  no event  no event
# 146     event  no event  no event  no event  no event  no event  no event
# 147     event  no event  no event  no event     event  no event  no event
# 148  no event     event  no event  no event  no event  no event  no event
# 149     event  no event  no event  no event  no event  no event  no event
# 150     event  no event  no event     event     event  no event  no event
# 151  no event  no event     event  no event  no event  no event  no event
# 152  no event  no event  no event  no event  no event  no event  no event
# 153  no event  no event  no event  no event  no event  no event  no event
# 154  no event  no event  no event  no event  no event  no event  no event
# 155  no event  no event  no event  no event  no event  no event  no event
# 156  no event  no event  no event  no event  no event  no event  no event
# 157  no event  no event  no event  no event  no event  no event  no event
# 158  no event  no event     event  no event  no event  no event  no event
# 159  no event  no event  no event  no event  no event  no event  no event
# 160  no event  no event  no event  no event  no event  no event  no event
#
#            E8        E9       E10  ...        E20       E21       E22  \
# 1    no event  no event  no event  ...   no event  no event  no event
# 2    no event  no event  no event  ...   no event  no event  no event
# 3    no event  no event  no event  ...   no event  no event  no event
# 4    no event  no event  no event  ...   no event  no event  no event
# 5    no event  no event  no event  ...   no event  no event  no event
# 6    no event  no event  no event  ...   no event  no event  no event
# 7    no event  no event  no event  ...   no event  no event  no event
# 8    no event  no event  no event  ...   no event  no event  no event
# 9    no event  no event  no event  ...   no event  no event  no event
# 10   no event  no event  no event  ...   no event  no event  no event
# 11   no event  no event  no event  ...   no event  no event  no event
# 12   no event  no event  no event  ...   no event  no event  no event
# 13   no event  no event  no event  ...   no event  no event  no event
# 14   no event  no event  no event  ...   no event  no event  no event
# 15   no event  no event  no event  ...   no event  no event  no event
# 16   no event  no event  no event  ...   no event  no event  no event
# 17   no event  no event  no event  ...   no event  no event  no event
# 18   no event  no event  no event  ...   no event  no event  no event
# 19   no event  no event  no event  ...   no event  no event     event
# 20   no event  no event  no event  ...   no event  no event  no event
# 21   no event  no event  no event  ...   no event  no event  no event
# 22   no event  no event  no event  ...   no event  no event  no event
# 23   no event  no event  no event  ...   no event  no event  no event
# 24   no event  no event  no event  ...   no event  no event  no event
# 25   no event  no event  no event  ...   no event  no event  no event
# 26   no event  no event  no event  ...   no event  no event  no event
# 27   no event  no event  no event  ...   no event  no event  no event
# 28   no event  no event  no event  ...   no event  no event  no event
# 29   no event  no event  no event  ...   no event  no event  no event
# 30   no event     event  no event  ...   no event  no event  no event
# ..        ...       ...       ...  ...        ...       ...       ...
# 131     event  no event  no event  ...   no event  no event  no event
# 132  no event  no event  no event  ...   no event  no event  no event
# 133  no event  no event  no event  ...   no event  no event  no event
# 134  no event  no event  no event  ...   no event  no event  no event
# 135  no event  no event  no event  ...   no event  no event  no event
# 136  no event  no event  no event  ...   no event  no event  no event
# 137     event  no event  no event  ...   no event  no event  no event
# 138  no event  no event  no event  ...   no event  no event  no event
# 139  no event  no event  no event  ...   no event  no event  no event
# 140  no event  no event  no event  ...   no event  no event  no event
# 141  no event  no event  no event  ...   no event  no event  no event
# 142  no event  no event  no event  ...      event  no event  no event
# 143  no event  no event  no event  ...   no event  no event  no event
# 144  no event  no event  no event  ...   no event  no event  no event
# 145  no event  no event  no event  ...   no event  no event  no event
# 146  no event  no event  no event  ...   no event  no event  no event
# 147  no event  no event  no event  ...   no event  no event  no event
# 148     event  no event  no event  ...   no event  no event  no event
# 149  no event  no event  no event  ...   no event  no event  no event
# 150  no event  no event  no event  ...   no event  no event  no event
# 151  no event  no event  no event  ...   no event  no event  no event
# 152  no event  no event  no event  ...   no event  no event  no event
# 153  no event  no event  no event  ...   no event  no event  no event
# 154  no event  no event  no event  ...   no event  no event  no event
# 155  no event  no event  no event  ...   no event  no event  no event
# 156  no event  no event  no event  ...   no event  no event  no event
# 157  no event  no event  no event  ...   no event  no event  no event
# 158  no event  no event  no event  ...   no event  no event  no event
# 159  no event  no event  no event  ...   no event  no event  no event
# 160  no event  no event  no event  ...   no event  no event  no event
#
#           E23       E24       E25       E26       E27       E28 group
# 1    no event  no event  no event  no event  no event  no event     A
# 2    no event  no event  no event  no event  no event  no event     A
# 3    no event  no event  no event  no event  no event  no event     A
# 4    no event  no event  no event  no event  no event  no event     A
# 5    no event  no event  no event  no event  no event  no event     A
# 6    no event  no event  no event  no event  no event  no event     A
# 7    no event  no event  no event  no event  no event  no event     A
# 8    no event  no event  no event  no event  no event  no event     A
# 9    no event  no event  no event  no event  no event  no event     A
# 10   no event  no event  no event  no event  no event  no event     A
# 11   no event  no event  no event  no event  no event  no event     A
# 12   no event  no event  no event  no event  no event     event     A
# 13   no event  no event  no event  no event  no event  no event     A
# 14   no event  no event  no event  no event  no event  no event     A
# 15   no event  no event  no event  no event  no event     event     A
# 16   no event  no event  no event  no event  no event  no event     A
# 17   no event  no event  no event  no event  no event  no event     A
# 18   no event  no event  no event  no event  no event     event     A
# 19   no event  no event  no event  no event  no event     event     A
# 20   no event  no event  no event  no event  no event     event     A
# 21   no event  no event  no event  no event  no event  no event     A
# 22   no event  no event  no event  no event  no event     event     A
# 23   no event  no event  no event  no event  no event  no event     A
# 24   no event  no event  no event  no event  no event     event     A
# 25   no event  no event  no event  no event  no event     event     A
# 26   no event  no event  no event  no event     event     event     A
# 27   no event  no event  no event  no event  no event  no event     A
# 28   no event  no event  no event  no event  no event     event     A
# 29   no event  no event  no event  no event  no event     event     A
# 30   no event  no event  no event  no event  no event     event     A
# ..        ...       ...       ...       ...       ...       ...   ...
# 131  no event  no event  no event  no event  no event     event     B
# 132  no event  no event  no event  no event  no event  no event     B
# 133  no event  no event  no event  no event  no event     event     B
# 134  no event  no event  no event  no event  no event     event     B
# 135  no event  no event  no event  no event  no event     event     B
# 136  no event  no event  no event  no event  no event  no event     B
# 137  no event  no event  no event  no event  no event     event     B
# 138  no event  no event  no event  no event  no event     event     B
# 139  no event  no event  no event  no event  no event     event     B
# 140  no event  no event  no event  no event  no event  no event     B
# 141  no event  no event  no event  no event  no event  no event     B
# 142  no event  no event  no event  no event  no event     event     B
# 143  no event  no event  no event  no event  no event     event     B
# 144  no event  no event  no event  no event  no event     event     B
# 145  no event  no event  no event  no event  no event  no event     B
# 146  no event  no event  no event  no event  no event     event     B
# 147  no event  no event  no event  no event  no event     event     B
# 148  no event  no event  no event  no event  no event     event     B
# 149  no event  no event  no event  no event  no event     event     B
# 150  no event  no event  no event  no event  no event     event     B
# 151  no event  no event  no event  no event  no event     event     B
# 152  no event  no event  no event  no event  no event  no event     B
# 153  no event  no event  no event  no event  no event  no event     B
# 154  no event  no event  no event  no event  no event  no event     B
# 155  no event  no event  no event  no event  no event  no event     B
# 156  no event  no event  no event  no event  no event  no event     B
# 157  no event  no event  no event  no event  no event  no event     B
# 158  no event  no event  no event  no event  no event     event     B
# 159  no event  no event  no event  no event  no event  no event     B
# 160  no event  no event  no event  no event  no event  no event     B
#
# [160 rows x 29 columns]

# %% [markdown]
# Characterizing Monte Carlo samples
# ----
#
# Given a bunch of random numbers from a simulaiton experiment, one of the first steps is to visualize the CDF and PDF.

# %% [markdown]
# ### Estimating the CDF

# %%
# Make up some random data
x = np.concatenate([np.random.normal(0, 1, 10000), 
                    np.random.normal(4, 1, 10000)])

# %%
# Roll our own ECDF function

def ecdf(x):
    """Return empirical CDF of x."""
    
    sx = np.sort(x)
    cdf = (1.0 + np.arange(len(sx)))/len(sx)
    return sx, cdf

# %%
sx, y = ecdf(x)
plt.plot(sx, y);

# %% [markdown]
# #### Using library routines

# %%
from statsmodels.distributions.empirical_distribution import ECDF

ecdf = ECDF(x)
plt.plot(ecdf.x, ecdf.y);

# %% [markdown]
# ### Estimating the PDF
#
# The simplest is to plot a normalized histogram as shown above, but we will also look at how to estimate density functions using kernel density estimation.

# %% [markdown]
# ### Kernel density estimation
#
# Kernel density estimation is a form of convolution, usually with a symmetric kenrel (e.g. a Gaussian). The degree of smoothing is determined by a bandwidth parameter.

# %%
def epanechnikov(u):
    """Epanechnikov kernel."""
    return np.where(np.abs(u) <= np.sqrt(5), 3/(4*np.sqrt(5)) * (1 - u*u/5.0), 0)

# %%
def silverman(y):
    """Find bandwidth using heuristic suggested by Silverman
    .9 min(standard deviation, interquartile range/1.34)n−1/5
    """
    n = len(y)
    iqr = np.subtract(*np.percentile(y, [75, 25]))
    h = 0.9*np.min([y.std(ddof=1), iqr/1.34])*n**-0.2
    return h

# %%
def kde(x, y, bandwidth=silverman, kernel=epanechnikov):
    """Returns kernel density estimate.
    x are the points for evaluation
    y is the data to be fitted
    bandwidth is a function that returens the smoothing parameter h
    kernel is a function that gives weights to neighboring data
    """
    h = bandwidth(y)
    return np.sum(kernel((x-y[:, None])/h)/h, axis=0)/len(y)

# %%
xs = np.linspace(-5,8,100)
density = kde(xs, x)
plt.plot(xs, density);

# %% [markdown]
# #### Using library routines
#
# There are several kernel density estimation routines available in scipy, statsmodels and scikit-leran. Here we will use the scikits-learn and statsmodels routine as examples.

# %%
import statsmodels.api as sm

dens = sm.nonparametric.KDEUnivariate(x)
dens.fit(kernel='gau')
plt.plot(xs, dens.evaluate(xs));

# %%
from sklearn.neighbors import KernelDensity 

# expects n x p matrix with p features
x.shape = (len(x), 1)
xs.shape = (len(xs), 1)

kde = KernelDensity(kernel='epanechnikov', bandwidth=0.5).fit(x)
dens = np.exp(kde.score_samples(xs))
plt.plot(xs, dens);

# %% [markdown]
# ### Using splines
#
# A quick alternative is to smooth the ECDF and find the PDF as its derivative, but the tails cannot be accurately estimated with this approach and may even be negative.

# %%
from scipy.interpolate import UnivariateSpline

x.shape = (len(x),)
xs.shape = (len(xs), )
ecdf = ECDF(x)
f = UnivariateSpline(ecdf.x[1::50], ecdf.y[1::50], s=0.0005)
plt.plot(xs, f(xs, nu=1)); # nu=1 means first derivative
